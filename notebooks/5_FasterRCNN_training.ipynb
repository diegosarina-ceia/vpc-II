# %% [markdown]
# # Faster RCNN - Entrenamientos

# %% [markdown]
# El entrenamiento de faster se realizo únicamente con el dataset 3 debido a que ya habíamos identificado el problema del etiquetado durante el entrenamiento de las otras arquitecturas.

# %% [markdown]
# ## Descarga del dataset

# %% [markdown]
# A continuación se procede a descargar el dataset

# %%
import os
import gdown

datasets_parent_dir = "datasets"
os.makedirs(datasets_parent_dir, exist_ok=True)

dataset_dir = os.path.join(datasets_parent_dir, "dataset_coco_3")
os.makedirs(dataset_dir, exist_ok=True)

# Definir la ruta para el archivo ZIP
destination = os.path.join(dataset_dir, 'dataset_coco_3.zip')

# Descargar el archivo desde Google Drive
gdown.download(id="19uIFLXV7ku0e7IAqKzmOAei9PUqfFdPg", output=destination, quiet=False)

# Descomprimir el archivo ZIP en la carpeta del dataset
# !unzip "{destination}" -d "{dataset_dir}/"

# Eliminar el archivo ZIP después de descomprimir
os.remove(destination)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=19uIFLXV7ku0e7IAqKzmOAei9PUqfFdPg
# From (redirected): https://drive.google.com/uc?id=19uIFLXV7ku0e7IAqKzmOAei9PUqfFdPg&confirm=t&uuid=3c7526a6-e5b3-4db1-a49b-2dff98143f30
# To: /home/isidro-marco/proyectos/CEIA/materias/bimestre4/vc2/vpc-II/datasets/dataset_coco_3/dataset_coco_3.zip
# 100%|██████████| 293M/293M [00:20<00:00, 14.4MB/s]
# Archive:  datasets/dataset_coco_3/dataset_coco_3.zip
#    creating: datasets/dataset_coco_3/test/
#   inflating: datasets/dataset_coco_3/test/train_121_png_jpg.rf.a7ca1cb50a79073ac64e5508f9b476d5.jpg
#   inflating: datasets/dataset_coco_3/test/train_124_png_jpg.rf.5b014b1b3cda024d60959bd7c4dd127a.jpg
#   inflating: datasets/dataset_coco_3/test/train_130_png_jpg.rf.3c1ddb33a79f32a6103d6f51b0420fa2.jpg
#   inflating: datasets/dataset_coco_3/test/train_13_png_jpg.rf.9d96cc7ec5368e3a0ca194de15ba184f.jpg
#   inflating: datasets/dataset_coco_3/test/train_142_png_jpg.rf.cc7b40022c65b9180d4bca8957d2979b.jpg
#   inflating: datasets/dataset_coco_3/test/train_148_png_jpg.rf.1554ad2bd6cb4fde6e0eea4b04acd442.jpg
#   inflating: datasets/dataset_coco_3/test/train_151_png_jpg.rf.0ab95d8ea76584566a8593eca074321a.jpg
#   inflating: datasets/dataset_coco_3/test/train_158_png_jpg.rf.bbe8ff78b3f8279699e11513d5198277.jpg
#   inflating: datasets/dataset_coco_3/test/train_166_png_jpg.rf.f1b97a64169a5ee209291ab876e74219.jpg
#   inflating: datasets/dataset_coco_3/test/train_167_png_jpg.rf.40729047ec217171814b57b396c88e38.jpg
#   inflating: datasets/dataset_coco_3/test/train_168_png_jpg.rf.67e2497f2b1716c9a30f19ab9df0e980.jpg
#   inflating: datasets/dataset_coco_3/test/train_189_png_jpg.rf.dbf488ae2e796cf7c225518f22dc45ca.jpg
#   inflating: datasets/dataset_coco_3/test/train_18_png_jpg.rf.8308b6146799efd878b2da302356d6a4.jpg
#   inflating: datasets/dataset_coco_3/test/train_192_png_jpg.rf.9dae4fe545fa655fd35d92f2a19d941b.jpg
#   inflating: datasets/dataset_coco_3/test/train_200_png_jpg.rf.c668b9f8f8f5ccc3afffb33918fc7241.jpg
#   inflating: datasets/dataset_coco_3/test/train_204_png_jpg.rf.48c2aef29b60a3906e1878e37ad37690.jpg
#   inflating: datasets/dataset_coco_3/test/train_213_png_jpg.rf.35b8070459aced6e65477c23e4e66d52.jpg
#   inflating: datasets/dataset_coco_3/test/train_222_png_jpg.rf.9953a044bb0264cc4583e8a19c585dd3.jpg
#   inflating: datasets/dataset_coco_3/test/train_225_png_jpg.rf.63f16a27dbbd45848d91510ef428f5e0.jpg
#   inflating: datasets/dataset_coco_3/test/train_226_png_jpg.rf.18a79f7bb9327e9a14d3a27656564747.jpg
#   inflating: datasets/dataset_coco_3/test/train_23_png_jpg.rf.12f28e47762ee8ff9dfa49a77e6ceae9.jpg
#   inflating: datasets/dataset_coco_3/test/train_243_png_jpg.rf.83edf876c9830744b42a9a4f3afdbd40.jpg
#   inflating: datasets/dataset_coco_3/test/train_261_png_jpg.rf.36af4059ec2ed389bba564d0e22f874f.jpg
#   inflating: datasets/dataset_coco_3/test/train_27_png_jpg.rf.f072472cf51f9254bd314d1fc99091ba.jpg
#   inflating: datasets/dataset_coco_3/test/train_284_png_jpg.rf.30d1c97f53f6e978a73421ebb74b3e3c.jpg
#   inflating: datasets/dataset_coco_3/test/train_289_png_jpg.rf.98f556cdd2dd037d375e4b3e7e5bcb9a.jpg
#   inflating: datasets/dataset_coco_3/test/train_296_png_jpg.rf.203b7893b0fc23688bb111d69bd4771b.jpg
#   inflating: datasets/dataset_coco_3/test/train_312_png_jpg.rf.331c7ae760f431dc3873b335f663400d.jpg
#   inflating: datasets/dataset_coco_3/test/train_315_png_jpg.rf.a4138ffa7cb4c1384044389907e5154c.jpg
#   inflating: datasets/dataset_coco_3/test/train_334_png_jpg.rf.fe4a72604f2cee4c41fbf140591f5ff6.jpg
#   inflating: datasets/dataset_coco_3/test/train_335_png_jpg.rf.0962a84a6c7b5f3745e962a5165cb2c7.jpg
#   inflating: datasets/dataset_coco_3/test/train_355_png_jpg.rf.aa4044d7fd7a18ed000afd53a5765bb2.jpg
#   inflating: datasets/dataset_coco_3/test/train_360_png_jpg.rf.78a1b5349f1e7b5f3bf68324c94104bd.jpg
#   inflating: datasets/dataset_coco_3/test/train_369_png_jpg.rf.d49fa8c759afd6051b5df259657a7df0.jpg
#   inflating: datasets/dataset_coco_3/test/train_370_png_jpg.rf.dc8e274b9abc125edb8c4c19975500d2.jpg
#   inflating: datasets/dataset_coco_3/test/train_391_png_jpg.rf.22274f032fd8232e0e6e34ff3cbf39c1.jpg
#   inflating: datasets/dataset_coco_3/test/train_39_png_jpg.rf.29cb3aa033c87b79ed9ea4909065335e.jpg
#   inflating: datasets/dataset_coco_3/test/train_413_png_jpg.rf.2e1b8a3ba955c781974035efb7018fe7.jpg
#   inflating: datasets/dataset_coco_3/test/train_415_png_jpg.rf.030222fc1f6e1672459b2fa240915cab.jpg
#   inflating: datasets/dataset_coco_3/test/train_421_png_jpg.rf.688150f51d08e6c614ac8a35fcedd78c.jpg
#   inflating: datasets/dataset_coco_3/test/train_422_png_jpg.rf.eb1ae3b6175bc0940db23d8dae37bd05.jpg
#   inflating: datasets/dataset_coco_3/test/train_426_png_jpg.rf.3114f603da98838285b868e67615be86.jpg
#   inflating: datasets/dataset_coco_3/test/train_427_png_jpg.rf.e952d7f0b4c9ec8e86e52e97f83a11b8.jpg
#   inflating: datasets/dataset_coco_3/test/train_447_png_jpg.rf.88a3ea1b47e9997acb187d0ac592d46a.jpg
#   inflating: datasets/dataset_coco_3/test/train_448_png_jpg.rf.d5f1d9cb989ce49f761a84b551dd5d63.jpg
#   inflating: datasets/dataset_coco_3/test/train_460_png_jpg.rf.b115362d0f4b45844101c3d441c462c4.jpg
#   inflating: datasets/dataset_coco_3/test/train_465_png_jpg.rf.f0d8104ebcad461ca76cf2aef1320dd5.jpg
#   inflating: datasets/dataset_coco_3/test/train_46_png_jpg.rf.2c14b075644d14d8223fe986a733075b.jpg
#   inflating: datasets/dataset_coco_3/test/train_470_png_jpg.rf.9566c31b3ed12b1daea2aad1bcbdbd86.jpg
#   inflating: datasets/dataset_coco_3/test/train_473_png_jpg.rf.562dd95a7d5aecb3ab4ba67ea0b18957.jpg
#   inflating: datasets/dataset_coco_3/test/train_488_png_jpg.rf.14407d57336c1c40eb8d66c7849ef345.jpg
#   inflating: datasets/dataset_coco_3/test/train_48_png_jpg.rf.778e52757d2c957a0f7ee0d1e84dca2c.jpg
#   inflating: datasets/dataset_coco_3/test/train_494_png_jpg.rf.cbe27237429e3531f252aa570bf3d8c6.jpg
#   inflating: datasets/dataset_coco_3/test/train_49_png_jpg.rf.a94d582a1f316122eac6380d66756da2.jpg
#   inflating: datasets/dataset_coco_3/test/train_530_png_jpg.rf.b3205e4c91761c7d8b40cccdcc044406.jpg
#   inflating: datasets/dataset_coco_3/test/train_536_png_jpg.rf.5b13d1a4df533d7846bb1fccb97eecbe.jpg
#   inflating: datasets/dataset_coco_3/test/train_561_png_jpg.rf.61cd6144d929fa0d4ce97cbbbf668d3c.jpg
#   inflating: datasets/dataset_coco_3/test/train_565_png_jpg.rf.6406511a48a73fbc933002a8814fa86a.jpg
#   inflating: datasets/dataset_coco_3/test/train_573_png_jpg.rf.a34b9c3a936421fe9488ffc050316b57.jpg
#   inflating: datasets/dataset_coco_3/test/train_580_png_jpg.rf.c5ea0eb476f0046d56ccd7b9392e1fc5.jpg
#   inflating: datasets/dataset_coco_3/test/train_582_png_jpg.rf.3b4c2d14136da01aae6ddb94f95e6182.jpg
#   inflating: datasets/dataset_coco_3/test/train_588_png_jpg.rf.7b30526e2dfedd060f900dd6d8953c39.jpg
#   inflating: datasets/dataset_coco_3/test/train_595_png_jpg.rf.378c8c4561ac83c59898dbb32b1e2ec8.jpg
#   inflating: datasets/dataset_coco_3/test/train_619_png_jpg.rf.4923ad701369f842725b031feabeee9b.jpg
#   inflating: datasets/dataset_coco_3/test/train_620_png_jpg.rf.6c3faa9197712e8bef474af53cbeda16.jpg
#   inflating: datasets/dataset_coco_3/test/train_651_png_jpg.rf.eee84e379425002270b5afa7c7893a3d.jpg
#   inflating: datasets/dataset_coco_3/test/train_655_png_jpg.rf.b7ee017203fbd2c6c4cbd2023fa1575b.jpg
#   inflating: datasets/dataset_coco_3/test/train_676_png_jpg.rf.49f8d5247d7099ace5e0f4c27cda1b78.jpg
#   inflating: datasets/dataset_coco_3/test/train_683_png_jpg.rf.237e954a4a54b08c5cb7625b547582ca.jpg
#   inflating: datasets/dataset_coco_3/test/train_692_png_jpg.rf.892dd275f0dd55bbf0124beca680d37d.jpg
#   inflating: datasets/dataset_coco_3/test/train_71_png_jpg.rf.e7aa8c1da7eb906f4451aaff370e4bb1.jpg
#   inflating: datasets/dataset_coco_3/test/train_77_png_jpg.rf.ab36412c3996f20fe76ba5e8a913dd6a.jpg
#   inflating: datasets/dataset_coco_3/test/train_80_png_jpg.rf.93793269ec1c5d613d34ee50a9106ff2.jpg
#   inflating: datasets/dataset_coco_3/test/train_8_png_jpg.rf.654f8c862a6fceb4670701f071363c29.jpg
#   inflating: datasets/dataset_coco_3/test/train_91_png_jpg.rf.680518b104f1eff3aba3dfef3dc52357.jpg
#   inflating: datasets/dataset_coco_3/test/val_13_png_jpg.rf.6f1e778800cd73096c1644a0a0c9d79c.jpg
#   inflating: datasets/dataset_coco_3/test/val_1_png_jpg.rf.2cf377a017b8f0f347559816c2c2ced6.jpg
#   inflating: datasets/dataset_coco_3/test/val_20_png_jpg.rf.325f1dfbd28884dd2b689c685136ea27.jpg
#   inflating: datasets/dataset_coco_3/test/val_23_png_jpg.rf.de3bfa6723b16d615f3fe852509265da.jpg
#   inflating: datasets/dataset_coco_3/test/val_43_png_jpg.rf.05dad35b0f17c8c854a2462c50838c70.jpg
#   inflating: datasets/dataset_coco_3/test/_annotations.coco.json
#    creating: datasets/dataset_coco_3/train/
#   inflating: datasets/dataset_coco_3/train/train_0_png_jpg.rf.c3c9948f971dd004f59ae5874268c605.jpg
#   inflating: datasets/dataset_coco_3/train/train_0_png_jpg.rf.cd21c1ea2e57f2bd223677f64fa27a46.jpg
#   inflating: datasets/dataset_coco_3/train/train_0_png_jpg.rf.e51b77779d28b29e9a415c9b38e317e9.jpg
#   inflating: datasets/dataset_coco_3/train/train_100_png_jpg.rf.10927e5d21aa084e8801da5f12e9441d.jpg
#   inflating: datasets/dataset_coco_3/train/train_100_png_jpg.rf.139edade6e20a60eec499c29bb0116ac.jpg
#   inflating: datasets/dataset_coco_3/train/train_100_png_jpg.rf.4e1d4fe3ae9919079db098562b065efc.jpg
#   inflating: datasets/dataset_coco_3/train/train_102_png_jpg.rf.6d1147264d3844dbfa10760eee7d337c.jpg
#   inflating: datasets/dataset_coco_3/train/train_102_png_jpg.rf.e1415c6e299b9a53313637b4e798e758.jpg
#   inflating: datasets/dataset_coco_3/train/train_102_png_jpg.rf.e3152338f8573c0ae37975af2de3d9b7.jpg
#   inflating: datasets/dataset_coco_3/train/train_103_png_jpg.rf.1a6ecd2a280038bb524b449ee4d25020.jpg
#   inflating: datasets/dataset_coco_3/train/train_103_png_jpg.rf.53463458a240776c9f42f88702fd3024.jpg
#   inflating: datasets/dataset_coco_3/train/train_103_png_jpg.rf.66f0c77faff08bc619cf34bed5e4a467.jpg
#   inflating: datasets/dataset_coco_3/train/train_104_png_jpg.rf.98ae8525bee45e8f9a00423ba9d25b20.jpg
#   inflating: datasets/dataset_coco_3/train/train_104_png_jpg.rf.d192cafc76dfbbf925545e0156d20bfe.jpg
#   inflating: datasets/dataset_coco_3/train/train_104_png_jpg.rf.f5af0652a52c0c2209f3081ab9493e44.jpg
#   inflating: datasets/dataset_coco_3/train/train_105_png_jpg.rf.566fbc6be9ace35613c5912921e209bf.jpg
#   inflating: datasets/dataset_coco_3/train/train_105_png_jpg.rf.9d94e1be883365687deda973fd1788bd.jpg
#   inflating: datasets/dataset_coco_3/train/train_105_png_jpg.rf.d072ac0e241311db07c7b0976ff63adf.jpg
#   inflating: datasets/dataset_coco_3/train/train_106_png_jpg.rf.a3d134e9be5f296d9e850c9a081939c6.jpg
#   inflating: datasets/dataset_coco_3/train/train_106_png_jpg.rf.d51cde944761decfa4282601faba3772.jpg
#   inflating: datasets/dataset_coco_3/train/train_106_png_jpg.rf.df5f50a6c23d677a389007562f90cb39.jpg
#   inflating: datasets/dataset_coco_3/train/train_107_png_jpg.rf.7c8f0c45d7338318b0fe0850fbe93af3.jpg
#   inflating: datasets/dataset_coco_3/train/train_107_png_jpg.rf.a76fb2d5ba47f0c067c5a2e2d22cf73f.jpg
#   inflating: datasets/dataset_coco_3/train/train_107_png_jpg.rf.b56463e3814292a875703a209c74820c.jpg
#   inflating: datasets/dataset_coco_3/train/train_108_png_jpg.rf.11db309874275e26d7522cca06be9c2f.jpg
#   inflating: datasets/dataset_coco_3/train/train_108_png_jpg.rf.20b8b4c838eab379aae67a7322a2f020.jpg
#   inflating: datasets/dataset_coco_3/train/train_108_png_jpg.rf.fcc72c09de7f96922abd3602f11d968d.jpg
#   inflating: datasets/dataset_coco_3/train/train_109_png_jpg.rf.6f3cc3d6fc5fe56e364f55b50f26ed57.jpg
#   inflating: datasets/dataset_coco_3/train/train_109_png_jpg.rf.76c566647850dca34b17c521c95b3b96.jpg
#   inflating: datasets/dataset_coco_3/train/train_109_png_jpg.rf.b55ddcae220cd9dd3253738177524559.jpg
#   inflating: datasets/dataset_coco_3/train/train_10_png_jpg.rf.50c30ea07b4d239e3010323cee7543b5.jpg
#   inflating: datasets/dataset_coco_3/train/train_10_png_jpg.rf.872bae68d331e3a670ef5e5f250919ea.jpg
#   inflating: datasets/dataset_coco_3/train/train_10_png_jpg.rf.8f3d08bfcd537330b08d76a278ac645b.jpg
#   inflating: datasets/dataset_coco_3/train/train_10_png_jpg.rf.b3d1b0d84839e7658e96cbb50983e646.jpg
#   inflating: datasets/dataset_coco_3/train/train_10_png_jpg.rf.d1b4f5c11100e387945a5e826ccd77d6.jpg
#   inflating: datasets/dataset_coco_3/train/train_10_png_jpg.rf.e349293846178954a866e2f22cd82cda.jpg
#   inflating: datasets/dataset_coco_3/train/train_112_png_jpg.rf.0448accb03c2460d045863803ac29011.jpg
#   inflating: datasets/dataset_coco_3/train/train_112_png_jpg.rf.0a4e6cc9d99db863257cacaf7e2e28f9.jpg
#   inflating: datasets/dataset_coco_3/train/train_112_png_jpg.rf.b756224fe805c4f74fc9bc8b152aef2d.jpg
#   inflating: datasets/dataset_coco_3/train/train_113_png_jpg.rf.93f37378aaab50e3e04fabf85d2b0aa9.jpg
#   inflating: datasets/dataset_coco_3/train/train_113_png_jpg.rf.cdb310415bef0cb7d2237d61644b9a9a.jpg
#   inflating: datasets/dataset_coco_3/train/train_113_png_jpg.rf.f165517370b3f8cc43e7f86140535044.jpg
#   inflating: datasets/dataset_coco_3/train/train_114_png_jpg.rf.3f2c267f5f1f24c5a8b1f10ceb37fa49.jpg
#   inflating: datasets/dataset_coco_3/train/train_114_png_jpg.rf.801bf4fdbfdd7c71724a789695b238a6.jpg
#   inflating: datasets/dataset_coco_3/train/train_114_png_jpg.rf.fd89db5170bd8daaf376caf3570e424d.jpg
#   inflating: datasets/dataset_coco_3/train/train_115_png_jpg.rf.0de5cf2c9a401bf8d0d0cc3f996d192b.jpg
#   inflating: datasets/dataset_coco_3/train/train_115_png_jpg.rf.4223f13d3b193a280c9a4fc2a9a5461e.jpg
#   inflating: datasets/dataset_coco_3/train/train_115_png_jpg.rf.bd56154ccc3486d7edc41af8ae16174b.jpg
#   inflating: datasets/dataset_coco_3/train/train_116_png_jpg.rf.8acb392def98a17c11297cbe3723fe72.jpg
#   inflating: datasets/dataset_coco_3/train/train_116_png_jpg.rf.c1935b67d534b0f991e7fd9882276ba1.jpg
#   inflating: datasets/dataset_coco_3/train/train_116_png_jpg.rf.c1cb0c415d2552a7ec9eb044fc1690e3.jpg
#   inflating: datasets/dataset_coco_3/train/train_118_png_jpg.rf.758cd9c001232f9b0907245643fad482.jpg
#   inflating: datasets/dataset_coco_3/train/train_118_png_jpg.rf.7cace470e6bbc74927edcc2375e95c51.jpg
#   inflating: datasets/dataset_coco_3/train/train_118_png_jpg.rf.d50c95070e9e48faca5304aa564a68e7.jpg
#   inflating: datasets/dataset_coco_3/train/train_11_png_jpg.rf.20c137a9887c1d26caf36bcb12fff661.jpg
#   inflating: datasets/dataset_coco_3/train/train_11_png_jpg.rf.50c3d5ef551987faaad7b36dc9582548.jpg
#   inflating: datasets/dataset_coco_3/train/train_11_png_jpg.rf.ba7cded527eef3bb8fbc7f404fe7a393.jpg
#   inflating: datasets/dataset_coco_3/train/train_11_png_jpg.rf.be2eccb8fe4f94af851752faa9eb3166.jpg
#   inflating: datasets/dataset_coco_3/train/train_11_png_jpg.rf.e7c896e0c2f5671b79980100151b2c6a.jpg
#   inflating: datasets/dataset_coco_3/train/train_11_png_jpg.rf.f2ef8fab152893f4956db56685ea0865.jpg
#   inflating: datasets/dataset_coco_3/train/train_120_png_jpg.rf.26d9d91e75e3b4b990d7fb3267e0a380.jpg
#   inflating: datasets/dataset_coco_3/train/train_120_png_jpg.rf.32afdf274b592de43c0dcb30c25d6c40.jpg
#   inflating: datasets/dataset_coco_3/train/train_120_png_jpg.rf.412fbb8cc5241acdd78797cbc53daede.jpg
#   inflating: datasets/dataset_coco_3/train/train_122_png_jpg.rf.67c5d96e2eacf72673df3dcf401b20a4.jpg
#   inflating: datasets/dataset_coco_3/train/train_122_png_jpg.rf.78dbb8f93c147daf5a380dab92cc9c08.jpg
#   inflating: datasets/dataset_coco_3/train/train_122_png_jpg.rf.c044919bb34d11a7bc35bf21ee4afd0d.jpg
#   inflating: datasets/dataset_coco_3/train/train_123_png_jpg.rf.11cc81d89718e2d92eaf2f96d22ca01a.jpg
#   inflating: datasets/dataset_coco_3/train/train_123_png_jpg.rf.7ce7a116669b52ae668e9074e6ca64d8.jpg
#   inflating: datasets/dataset_coco_3/train/train_123_png_jpg.rf.9c8809bd092f8a842a03f331fafe5896.jpg
#   inflating: datasets/dataset_coco_3/train/train_125_png_jpg.rf.110dae6b8ae755c2bca0b43ad716e15e.jpg
#   inflating: datasets/dataset_coco_3/train/train_125_png_jpg.rf.21014954608f9120bbe1f88edc5116eb.jpg
#   inflating: datasets/dataset_coco_3/train/train_125_png_jpg.rf.d6f165363a7c29a487490ad5e746215c.jpg
#   inflating: datasets/dataset_coco_3/train/train_126_png_jpg.rf.745751ab3c547689f82e0150fe41c185.jpg
#   inflating: datasets/dataset_coco_3/train/train_126_png_jpg.rf.78242f8990d97a144bfe54059fc24ea0.jpg
#   inflating: datasets/dataset_coco_3/train/train_126_png_jpg.rf.f4f7e1a8806351d0cc354fe91a94118f.jpg
#   inflating: datasets/dataset_coco_3/train/train_128_png_jpg.rf.5ac4528eb0f3ed56623635fb352b9433.jpg
#   inflating: datasets/dataset_coco_3/train/train_128_png_jpg.rf.a196399c92e722ea8731d05e5d250f90.jpg
#   inflating: datasets/dataset_coco_3/train/train_128_png_jpg.rf.da19913237269a6695feaa94d836eb5a.jpg
#   inflating: datasets/dataset_coco_3/train/train_129_png_jpg.rf.23a32b9198a1b0dd010e7f0a1db8fc4e.jpg
#   inflating: datasets/dataset_coco_3/train/train_129_png_jpg.rf.abacee8be3790d1999e1ef6cac35e922.jpg
#   inflating: datasets/dataset_coco_3/train/train_129_png_jpg.rf.ce08d2d50b1dae83c20ec661984e1030.jpg
#   inflating: datasets/dataset_coco_3/train/train_12_png_jpg.rf.589cd4d109d7a9cc5fb1f61511f92a7c.jpg
#   inflating: datasets/dataset_coco_3/train/train_12_png_jpg.rf.706b46ab6b2635c96598efc976a557b1.jpg
#   inflating: datasets/dataset_coco_3/train/train_12_png_jpg.rf.9d08943bbb5d85570ff6cde68946e064.jpg
#   inflating: datasets/dataset_coco_3/train/train_12_png_jpg.rf.b7eedc705f783c04efbcf03fc83bd07e.jpg
#   inflating: datasets/dataset_coco_3/train/train_12_png_jpg.rf.bb04cc0aaa5fde267890db80c8c00ec8.jpg
#   inflating: datasets/dataset_coco_3/train/train_12_png_jpg.rf.e912f4917f58856023c0e39a504831bf.jpg
#   inflating: datasets/dataset_coco_3/train/train_131_png_jpg.rf.2664572e4514020691f8b2c787b3dce1.jpg
#   inflating: datasets/dataset_coco_3/train/train_131_png_jpg.rf.872093ec47ca8d9f55b4335274425468.jpg
#   inflating: datasets/dataset_coco_3/train/train_131_png_jpg.rf.9adf7a2053ec957b707ea47ab57cf567.jpg
#   inflating: datasets/dataset_coco_3/train/train_132_png_jpg.rf.26b2e5f7d93d01186eff0eb188696fa3.jpg
#   inflating: datasets/dataset_coco_3/train/train_132_png_jpg.rf.2d67a32a864b72d42e6e8f8861e84fd8.jpg
#   inflating: datasets/dataset_coco_3/train/train_132_png_jpg.rf.faccee82e0d35ff66071482f080254bf.jpg
#   inflating: datasets/dataset_coco_3/train/train_133_png_jpg.rf.5401233cb6cdccc805006f5ce89a46fc.jpg
#   inflating: datasets/dataset_coco_3/train/train_133_png_jpg.rf.a0c1fad77bb8631b7bfc9f5dd1dcbc05.jpg
#   inflating: datasets/dataset_coco_3/train/train_133_png_jpg.rf.cd6100cb34a9e826964a8ff59b75b2be.jpg
#   inflating: datasets/dataset_coco_3/train/train_134_png_jpg.rf.d9c6017f811ba17ec03d16834acb4c3f.jpg
#   inflating: datasets/dataset_coco_3/train/train_134_png_jpg.rf.f28a4dafa24719d5e73d36d841581ce6.jpg
#   inflating: datasets/dataset_coco_3/train/train_134_png_jpg.rf.f37f05b5d1485ef7864ce6d1468fcd8e.jpg
#   inflating: datasets/dataset_coco_3/train/train_135_png_jpg.rf.85200b7620f24700e13248951a0cb8a6.jpg
#   inflating: datasets/dataset_coco_3/train/train_135_png_jpg.rf.894da449198dd588d21763ce0d97decb.jpg
#   inflating: datasets/dataset_coco_3/train/train_135_png_jpg.rf.cef85e46af053fa19033e7cb389c0781.jpg
#   inflating: datasets/dataset_coco_3/train/train_136_png_jpg.rf.00bf6bc8fcbba8231bb5ec6da02a6d4b.jpg
#   inflating: datasets/dataset_coco_3/train/train_136_png_jpg.rf.853c1a59ef88bdd2be925c7be323be19.jpg
#   inflating: datasets/dataset_coco_3/train/train_136_png_jpg.rf.9d7b4613bd2e32eb6ff6273f354f6ffa.jpg
#   inflating: datasets/dataset_coco_3/train/train_137_png_jpg.rf.62a19875c06621951e699033eb9d08e3.jpg
#   inflating: datasets/dataset_coco_3/train/train_137_png_jpg.rf.b6eebebbbcca12bf3086b2a30b4b607d.jpg
#   inflating: datasets/dataset_coco_3/train/train_137_png_jpg.rf.c5211cd91acbd1bc3e2a3d482b828786.jpg
#   inflating: datasets/dataset_coco_3/train/train_138_png_jpg.rf.a15a4379fd73a4922e35c3c31ac08486.jpg
#   inflating: datasets/dataset_coco_3/train/train_138_png_jpg.rf.bc3a05f7e3a1f91e60d80d98b3663cfd.jpg
#   inflating: datasets/dataset_coco_3/train/train_138_png_jpg.rf.e9e0c99d0697a606c6183dee33ee0400.jpg
#   inflating: datasets/dataset_coco_3/train/train_139_png_jpg.rf.5576d318627e07234a9d0409150ebcd4.jpg
#   inflating: datasets/dataset_coco_3/train/train_139_png_jpg.rf.94a262220dd605b8cc0606c217ad3b78.jpg
#   inflating: datasets/dataset_coco_3/train/train_139_png_jpg.rf.a3acb437e508a3177908ab9d64fa7809.jpg
#   inflating: datasets/dataset_coco_3/train/train_13_png_jpg.rf.a93ca017d59a672b3a0d2bdb31b27e89.jpg
#   inflating: datasets/dataset_coco_3/train/train_13_png_jpg.rf.dbad1c245a9e17997ee35860503b0514.jpg
#   inflating: datasets/dataset_coco_3/train/train_13_png_jpg.rf.ed5c95fe641c4f2dccb920a898760751.jpg
#   inflating: datasets/dataset_coco_3/train/train_140_png_jpg.rf.15bf64c33e2e43cbfc6701eb1aeda10b.jpg
#   inflating: datasets/dataset_coco_3/train/train_140_png_jpg.rf.6422e54dd823aed2bfa7d313921f6c7b.jpg
#   inflating: datasets/dataset_coco_3/train/train_140_png_jpg.rf.e59e6352af9ee19995a8ff6a690c8600.jpg
#   inflating: datasets/dataset_coco_3/train/train_141_png_jpg.rf.049f4156bd7c5c07890ec678c1c3cee7.jpg
#   inflating: datasets/dataset_coco_3/train/train_141_png_jpg.rf.4c5a5783a2e65d37a4199af69bf95784.jpg
#   inflating: datasets/dataset_coco_3/train/train_141_png_jpg.rf.8b9a580fe501e84e7483b1c169f72a34.jpg
#   inflating: datasets/dataset_coco_3/train/train_143_png_jpg.rf.1beee7ed3011947f73b9a5194d55b842.jpg
#   inflating: datasets/dataset_coco_3/train/train_143_png_jpg.rf.2985d01b610b19b34d03745fcc7d6380.jpg
#   inflating: datasets/dataset_coco_3/train/train_143_png_jpg.rf.c89a8a9381de0a2a4ee103446f703b59.jpg
#   inflating: datasets/dataset_coco_3/train/train_144_png_jpg.rf.1ba99ccbe10dff5df6549d18002167f3.jpg
#   inflating: datasets/dataset_coco_3/train/train_144_png_jpg.rf.488a9a07c676f5bad09be94df7130b73.jpg
#   inflating: datasets/dataset_coco_3/train/train_144_png_jpg.rf.be94628a080e0455c8ee54027bcb9f8a.jpg
#   inflating: datasets/dataset_coco_3/train/train_145_png_jpg.rf.229ffd082bbf665246f8ff089c86e5ae.jpg
#   inflating: datasets/dataset_coco_3/train/train_145_png_jpg.rf.d3ca70c8aab93050df95d7d70e89c9e7.jpg
#   inflating: datasets/dataset_coco_3/train/train_145_png_jpg.rf.f9bd87023cc9b6a4f5c95a6520565f8b.jpg
#   inflating: datasets/dataset_coco_3/train/train_146_png_jpg.rf.3d031431c228e3db7ed5a7eeaac7b4c7.jpg
#   inflating: datasets/dataset_coco_3/train/train_146_png_jpg.rf.3d4c4cff7b1e95e8c686f50efdd64120.jpg
#   inflating: datasets/dataset_coco_3/train/train_146_png_jpg.rf.3db3416da1813d8f225f4c9682123fa5.jpg
#   inflating: datasets/dataset_coco_3/train/train_147_png_jpg.rf.18234190c8e14bb017e887be71d2e68c.jpg
#   inflating: datasets/dataset_coco_3/train/train_147_png_jpg.rf.9e4f0837365422b672e9d0ccad756ae0.jpg
#   inflating: datasets/dataset_coco_3/train/train_147_png_jpg.rf.cf07d3b2e1633056b50f3cd328f17cfd.jpg
#   inflating: datasets/dataset_coco_3/train/train_149_png_jpg.rf.42e8fa07f415def8601378bfca94eb17.jpg
#   inflating: datasets/dataset_coco_3/train/train_149_png_jpg.rf.96845e13730364ed021018edc88b4640.jpg
#   inflating: datasets/dataset_coco_3/train/train_149_png_jpg.rf.a0d9327e73f042d7eb7ca30995948cfe.jpg
#   inflating: datasets/dataset_coco_3/train/train_14_png_jpg.rf.26af93dbb6a8e53553737d831e432653.jpg
#   inflating: datasets/dataset_coco_3/train/train_14_png_jpg.rf.55e41475f963475d49fb089c3124ab1e.jpg
#   inflating: datasets/dataset_coco_3/train/train_14_png_jpg.rf.8527ec4a50de24e3e4231b96c9062c31.jpg
#   inflating: datasets/dataset_coco_3/train/train_14_png_jpg.rf.8b2c0c502fd6d02197e6c0eef5f892d3.jpg
#   inflating: datasets/dataset_coco_3/train/train_14_png_jpg.rf.b62a06c17ea8cc6ee00e9e7c63969517.jpg
#   inflating: datasets/dataset_coco_3/train/train_14_png_jpg.rf.d1c8e736bc283f2c5c9dffa2f9954871.jpg
#   inflating: datasets/dataset_coco_3/train/train_150_png_jpg.rf.2ab1d83d79d5824f9f4762f07f0c6fa4.jpg
#   inflating: datasets/dataset_coco_3/train/train_150_png_jpg.rf.91ceda13631c4848e0d79bb361f64afb.jpg
#   inflating: datasets/dataset_coco_3/train/train_150_png_jpg.rf.d3b04e147bc8ff2906c7674639b32d3b.jpg
#   inflating: datasets/dataset_coco_3/train/train_153_png_jpg.rf.5468e246963587a24eb9b236365b269d.jpg
#   inflating: datasets/dataset_coco_3/train/train_153_png_jpg.rf.831fec203a402b35b8f8d62aa13c9c46.jpg
#   inflating: datasets/dataset_coco_3/train/train_153_png_jpg.rf.db9ce160a4aa989f12d723653b8768b2.jpg
#   inflating: datasets/dataset_coco_3/train/train_154_png_jpg.rf.0b29de20e4cccf48fee7bee526487467.jpg
#   inflating: datasets/dataset_coco_3/train/train_154_png_jpg.rf.89f4cdabe49766bd645ba4c0ac14f118.jpg
#   inflating: datasets/dataset_coco_3/train/train_154_png_jpg.rf.e71f6ce5cc44f59adb3429b40db8322c.jpg
#   inflating: datasets/dataset_coco_3/train/train_157_png_jpg.rf.1760e4959fedbd4090518ebed74772e1.jpg
#   inflating: datasets/dataset_coco_3/train/train_157_png_jpg.rf.437b28ddf99c9194e8ec3c2f06efac8f.jpg
#   inflating: datasets/dataset_coco_3/train/train_157_png_jpg.rf.d382f650dff22890cb58484e71df0a3f.jpg
#   inflating: datasets/dataset_coco_3/train/train_159_png_jpg.rf.3877c5c5b983d417ff8ca041df56962f.jpg
#   inflating: datasets/dataset_coco_3/train/train_159_png_jpg.rf.ed9083b4edabd1b81450738ecbd46f4f.jpg
#   inflating: datasets/dataset_coco_3/train/train_159_png_jpg.rf.f0059783ab6a3c0b483ae4786dc72a81.jpg
#   inflating: datasets/dataset_coco_3/train/train_15_png_jpg.rf.02563c04888c64a2711956e401fd9fb4.jpg
#   inflating: datasets/dataset_coco_3/train/train_15_png_jpg.rf.2462c67193a3bbd620cde92e10ef7dbb.jpg
#   inflating: datasets/dataset_coco_3/train/train_15_png_jpg.rf.87093d626f65e0f93e766751fdf84cbf.jpg
#   inflating: datasets/dataset_coco_3/train/train_15_png_jpg.rf.ab3f04dd23ee62fd8097b2ec1cba0450.jpg
#   inflating: datasets/dataset_coco_3/train/train_15_png_jpg.rf.c7b60d6179b985d9f174fd7235acb376.jpg
#   inflating: datasets/dataset_coco_3/train/train_15_png_jpg.rf.fd1bbe5ac885f2186ca494f033c5e12c.jpg
#   inflating: datasets/dataset_coco_3/train/train_160_png_jpg.rf.007ab6790fa74fc2b1e875a615ea11eb.jpg
#   inflating: datasets/dataset_coco_3/train/train_160_png_jpg.rf.ae3050b4dd4f5d9e9c93122a2035b4ba.jpg
#   inflating: datasets/dataset_coco_3/train/train_160_png_jpg.rf.f44d48ebe0911016f7e1524d6423d819.jpg
#   inflating: datasets/dataset_coco_3/train/train_161_png_jpg.rf.417cd9237d9aa01f13d12aca6847ad64.jpg
#   inflating: datasets/dataset_coco_3/train/train_161_png_jpg.rf.5f14df34e449e7694f757463509ae19c.jpg
#   inflating: datasets/dataset_coco_3/train/train_161_png_jpg.rf.e48f993e79720dde1c8f653adf3930d9.jpg
#   inflating: datasets/dataset_coco_3/train/train_162_png_jpg.rf.20de84d31c971a83d6cff791a5abef13.jpg
#   inflating: datasets/dataset_coco_3/train/train_162_png_jpg.rf.2c1b172ecfca5814a13596e8538d61b5.jpg
#   inflating: datasets/dataset_coco_3/train/train_162_png_jpg.rf.95a02666b0b56c5b36ade346beac709a.jpg
#   inflating: datasets/dataset_coco_3/train/train_163_png_jpg.rf.6da35c7ee86aa2b954ebf088a1000d03.jpg
#   inflating: datasets/dataset_coco_3/train/train_163_png_jpg.rf.bf79700044dcb30156aee4f4104f75da.jpg
#   inflating: datasets/dataset_coco_3/train/train_163_png_jpg.rf.ec3c6b1dd5a10a718dcaf2558f6c3cdb.jpg
#   inflating: datasets/dataset_coco_3/train/train_164_png_jpg.rf.0ee561176460f9cb771e9586ac7caa34.jpg
#   inflating: datasets/dataset_coco_3/train/train_164_png_jpg.rf.1487a2e4283154c299c57e9c6c3f6ae5.jpg
#   inflating: datasets/dataset_coco_3/train/train_164_png_jpg.rf.d95b52bbc62a8991775ae526dbdeee71.jpg
#   inflating: datasets/dataset_coco_3/train/train_165_png_jpg.rf.a82c2bedcee2e6cd0024a8b31d698326.jpg
#   inflating: datasets/dataset_coco_3/train/train_165_png_jpg.rf.b6c0f1dd8c34dd58e888fec0737030cd.jpg
#   inflating: datasets/dataset_coco_3/train/train_165_png_jpg.rf.e122a8351315c7f4118fc22bd4eb2698.jpg
#   inflating: datasets/dataset_coco_3/train/train_169_png_jpg.rf.49a81201b3da62012a57828b77633c22.jpg
#   inflating: datasets/dataset_coco_3/train/train_169_png_jpg.rf.a2f3cbd9e98c70a0d7630712eb900c32.jpg
#   inflating: datasets/dataset_coco_3/train/train_169_png_jpg.rf.d92f47856c6a7b72b627aaab57c8b715.jpg
#   inflating: datasets/dataset_coco_3/train/train_16_png_jpg.rf.36a0b43a7f70ed15a1655740f6211060.jpg
#   inflating: datasets/dataset_coco_3/train/train_16_png_jpg.rf.3c151d5baae7c2c2982808a3300cfe13.jpg
#   inflating: datasets/dataset_coco_3/train/train_16_png_jpg.rf.a57fda3917275ec1b8939e902ca7b13c.jpg
#   inflating: datasets/dataset_coco_3/train/train_16_png_jpg.rf.c45effdf0149498aec19e729b7af43f2.jpg
#   inflating: datasets/dataset_coco_3/train/train_16_png_jpg.rf.cba526ef597dc621f714e50043f760de.jpg
#   inflating: datasets/dataset_coco_3/train/train_16_png_jpg.rf.d8cd6e202315c169b4e5e70dcfe7cdfa.jpg
#   inflating: datasets/dataset_coco_3/train/train_170_png_jpg.rf.6a51b86023df7aa0f2635019ec412dd7.jpg
#   inflating: datasets/dataset_coco_3/train/train_170_png_jpg.rf.6e50d2fdaac989b7a12ad38f351b5ac3.jpg
#   inflating: datasets/dataset_coco_3/train/train_170_png_jpg.rf.a65e0e4fab9be23bbf051376c5f2fc18.jpg
#   inflating: datasets/dataset_coco_3/train/train_171_png_jpg.rf.151887dbd49f9880dbb2c997a281ab5b.jpg
#   inflating: datasets/dataset_coco_3/train/train_171_png_jpg.rf.d0c6badfcd1ddc0ed14d8e4dddfd5409.jpg
#   inflating: datasets/dataset_coco_3/train/train_171_png_jpg.rf.d9a892ec711dac900002becac690f61c.jpg
#   inflating: datasets/dataset_coco_3/train/train_172_png_jpg.rf.2228a90e2a3911bba59858afb210e286.jpg
#   inflating: datasets/dataset_coco_3/train/train_172_png_jpg.rf.4a7367a7289ab702929cea91063cf302.jpg
#   inflating: datasets/dataset_coco_3/train/train_172_png_jpg.rf.e0be3f9f050a08987a0fd910fe75f006.jpg
#   inflating: datasets/dataset_coco_3/train/train_173_png_jpg.rf.5bf67811a0ed24cdb9f54e25c7c90c66.jpg
#   inflating: datasets/dataset_coco_3/train/train_173_png_jpg.rf.5ea8a17693b0ac9eaac16f4913009ec4.jpg
#   inflating: datasets/dataset_coco_3/train/train_173_png_jpg.rf.b546fa8a7e622fbd37ceb9562465428d.jpg
#   inflating: datasets/dataset_coco_3/train/train_174_png_jpg.rf.24398e51af54d9011ca5f40d19a20d57.jpg
#   inflating: datasets/dataset_coco_3/train/train_174_png_jpg.rf.981505404dddf0ec7db7c8d7a00914a0.jpg
#   inflating: datasets/dataset_coco_3/train/train_174_png_jpg.rf.bb50516ec368ad11e9ad3e7f1386d5ad.jpg
#   inflating: datasets/dataset_coco_3/train/train_175_png_jpg.rf.3013028ea623960f6c91787bebc27938.jpg
#   inflating: datasets/dataset_coco_3/train/train_175_png_jpg.rf.74e3ff18cb0e6cdced1aab00e0029556.jpg
#   inflating: datasets/dataset_coco_3/train/train_175_png_jpg.rf.a84b8631621984f2fcd8d02b20b0d621.jpg
#   inflating: datasets/dataset_coco_3/train/train_177_png_jpg.rf.45170e78d36ade32226e7fecec500ac0.jpg
#   inflating: datasets/dataset_coco_3/train/train_177_png_jpg.rf.9165fa06f9c6cc81894bedaae39fd129.jpg
#   inflating: datasets/dataset_coco_3/train/train_177_png_jpg.rf.e97f7035be563708db91725183413b9c.jpg
#   inflating: datasets/dataset_coco_3/train/train_178_png_jpg.rf.43040109f89e310d11edcaf64784bc97.jpg
#   inflating: datasets/dataset_coco_3/train/train_178_png_jpg.rf.4502986ad4938dcddb4fe74dea9b8bd9.jpg
#   inflating: datasets/dataset_coco_3/train/train_178_png_jpg.rf.f4823e4ea5f732b7bc043739d3158a9a.jpg
#   inflating: datasets/dataset_coco_3/train/train_179_png_jpg.rf.52a76cabc0273c7d9ad42985302b5ff9.jpg
#   inflating: datasets/dataset_coco_3/train/train_179_png_jpg.rf.5b828582b84604f34e72830096017e45.jpg
#   inflating: datasets/dataset_coco_3/train/train_179_png_jpg.rf.77e17d8b9379218fed2611aa6cc24ce8.jpg
#   inflating: datasets/dataset_coco_3/train/train_17_png_jpg.rf.2396658c3a5fccb63772b0f85b2758f6.jpg
#   inflating: datasets/dataset_coco_3/train/train_17_png_jpg.rf.6514d5cbbe0d6b08ddf1c678eb781c41.jpg
#   inflating: datasets/dataset_coco_3/train/train_17_png_jpg.rf.7b1c3e62204c2e93abaf68c307740a83.jpg
#   inflating: datasets/dataset_coco_3/train/train_17_png_jpg.rf.bb0c42984e70ec1fb36610f1b1f0675e.jpg
#   inflating: datasets/dataset_coco_3/train/train_17_png_jpg.rf.caf51f66b6a77451e6cefc1c4269c371.jpg
#   inflating: datasets/dataset_coco_3/train/train_17_png_jpg.rf.e5a6fbea23078ecb57f69621c4629a68.jpg
#   inflating: datasets/dataset_coco_3/train/train_180_png_jpg.rf.5179571fd9dffaf83129e2ad02658610.jpg
#   inflating: datasets/dataset_coco_3/train/train_180_png_jpg.rf.7d287f040d472dc4a441ad422659d085.jpg
#   inflating: datasets/dataset_coco_3/train/train_180_png_jpg.rf.fd4d99d58ed16162730fd973f65e4c63.jpg
#   inflating: datasets/dataset_coco_3/train/train_182_png_jpg.rf.3efebfe5b811308ed280b78042d668b1.jpg
#   inflating: datasets/dataset_coco_3/train/train_182_png_jpg.rf.590e3e14cc7db713ae6952bfb82a4606.jpg
#   inflating: datasets/dataset_coco_3/train/train_182_png_jpg.rf.b7a9ff91852a20a56329649bfd0638b7.jpg
#   inflating: datasets/dataset_coco_3/train/train_184_png_jpg.rf.3eaeb698de06d5dcdec88341f4603ce0.jpg
#   inflating: datasets/dataset_coco_3/train/train_184_png_jpg.rf.6938b36f4ab81587ceeeb62b65e2d89b.jpg
#   inflating: datasets/dataset_coco_3/train/train_184_png_jpg.rf.8cc94a621e6f641a50c713e1d936dae7.jpg
#   inflating: datasets/dataset_coco_3/train/train_186_png_jpg.rf.1a1d230dbb3946cbb8c6b17c1e1ca203.jpg
#   inflating: datasets/dataset_coco_3/train/train_186_png_jpg.rf.5bbf83ed648010976aa9f973c4c89cfa.jpg
#   inflating: datasets/dataset_coco_3/train/train_186_png_jpg.rf.d6578ced0dbb9947434bb08f3950f81a.jpg
#   inflating: datasets/dataset_coco_3/train/train_187_png_jpg.rf.3dd50160ad4ec8336f88e6b130f0fb1f.jpg
#   inflating: datasets/dataset_coco_3/train/train_187_png_jpg.rf.5bb66a8f46bd8afc417167d936bd9e4b.jpg
#   inflating: datasets/dataset_coco_3/train/train_187_png_jpg.rf.72508bb85d69c5307b63d6bb438e7586.jpg
#   inflating: datasets/dataset_coco_3/train/train_188_png_jpg.rf.3ec6416cd526dd5ae0a24dbee0d6699a.jpg
#   inflating: datasets/dataset_coco_3/train/train_188_png_jpg.rf.83db8691c8e411c4bd840ce3d03d8085.jpg
#   inflating: datasets/dataset_coco_3/train/train_188_png_jpg.rf.b662f96c4ba15f83122aa187f3f0dd39.jpg
#   inflating: datasets/dataset_coco_3/train/train_18_png_jpg.rf.9b06536f1fbe5ba938b77878a7ec4d0c.jpg
#   inflating: datasets/dataset_coco_3/train/train_18_png_jpg.rf.a4dabbdc9de4d40349e84a8d68588a2e.jpg
#   inflating: datasets/dataset_coco_3/train/train_18_png_jpg.rf.a91b834f99a4a92fc6ecd660e4301483.jpg
#   inflating: datasets/dataset_coco_3/train/train_190_png_jpg.rf.272122f1d61ea5e2dde67c08d4aeb0d7.jpg
#   inflating: datasets/dataset_coco_3/train/train_190_png_jpg.rf.49fe928ca325954db52e07ee577fdba2.jpg
#   inflating: datasets/dataset_coco_3/train/train_190_png_jpg.rf.5328365c075c0dd58070d56e6ef601b3.jpg
#   inflating: datasets/dataset_coco_3/train/train_191_png_jpg.rf.2f1a23c6574c18ab9a1e4a881bf3e017.jpg
#   inflating: datasets/dataset_coco_3/train/train_191_png_jpg.rf.dbc0e087ac77cbfa0d986073703a6d98.jpg
#   inflating: datasets/dataset_coco_3/train/train_191_png_jpg.rf.ef8c1d1d33eb0dbc85135742f6104e7c.jpg
#   inflating: datasets/dataset_coco_3/train/train_193_png_jpg.rf.317ab6bdeb84139ac6f5b366c61c2e17.jpg
#   inflating: datasets/dataset_coco_3/train/train_193_png_jpg.rf.83de624a54d693e1b99574bb2baecfb4.jpg
#   inflating: datasets/dataset_coco_3/train/train_193_png_jpg.rf.98cd1a778cb54553c050e36b5a258ca0.jpg
#   inflating: datasets/dataset_coco_3/train/train_196_png_jpg.rf.6292bc30b4a87998cc219043988773ec.jpg
#   inflating: datasets/dataset_coco_3/train/train_196_png_jpg.rf.6fd5e40dd479e72037d2c333ba4d3127.jpg
#   inflating: datasets/dataset_coco_3/train/train_196_png_jpg.rf.e75dd93666c4b9d001498604c89a27a0.jpg
#   inflating: datasets/dataset_coco_3/train/train_197_png_jpg.rf.3aafb72182703501a5ebeacda6b6195f.jpg
#   inflating: datasets/dataset_coco_3/train/train_197_png_jpg.rf.5053ec10c2fca5a569d11299cfa2e9c4.jpg
#   inflating: datasets/dataset_coco_3/train/train_197_png_jpg.rf.bd0d5c1b54c9326ae78ca5fdc16b617c.jpg
#   inflating: datasets/dataset_coco_3/train/train_198_png_jpg.rf.496e29fd4d744804dbc18633b1c3f003.jpg
#   inflating: datasets/dataset_coco_3/train/train_198_png_jpg.rf.a8febc61951039a7f19412b023de8fbe.jpg
#   inflating: datasets/dataset_coco_3/train/train_198_png_jpg.rf.b2cf868ff375419f4a55280ab2fcf8ea.jpg
#   inflating: datasets/dataset_coco_3/train/train_199_png_jpg.rf.4e66e025426bbddb191cf1faeb3187bc.jpg
#   inflating: datasets/dataset_coco_3/train/train_199_png_jpg.rf.81abbaa2bc94e984b1f36beb99ff5b64.jpg
#   inflating: datasets/dataset_coco_3/train/train_199_png_jpg.rf.825705bddb81a9bf7f7f4b1214939a8e.jpg
#   inflating: datasets/dataset_coco_3/train/train_19_png_jpg.rf.0940a374a26a81bbe5724d4f87803720.jpg
#   inflating: datasets/dataset_coco_3/train/train_19_png_jpg.rf.1e7f8395cc868ae91e71b393d7cace59.jpg
#   inflating: datasets/dataset_coco_3/train/train_19_png_jpg.rf.4485b97ca36ec5328dfa00339ec2f22b.jpg
#   inflating: datasets/dataset_coco_3/train/train_19_png_jpg.rf.4814a8c7af5e84c839d9ca6ba423d9e5.jpg
#   inflating: datasets/dataset_coco_3/train/train_19_png_jpg.rf.66e0ec3577485b9bfc9b296f36b40f0a.jpg
#   inflating: datasets/dataset_coco_3/train/train_19_png_jpg.rf.a46ca8ad05988d9cd22d592ce8f03fc9.jpg
#   inflating: datasets/dataset_coco_3/train/train_201_png_jpg.rf.207342565e602f1e84744fa654602bb9.jpg
#   inflating: datasets/dataset_coco_3/train/train_201_png_jpg.rf.f113a30f5db44e6cd6e87c5cea7dcf81.jpg
#   inflating: datasets/dataset_coco_3/train/train_201_png_jpg.rf.f9b88984e2fc3eec87592f8a1e4e7b49.jpg
#   inflating: datasets/dataset_coco_3/train/train_202_png_jpg.rf.22a15e4ebc0c8621ca18820841466d02.jpg
#   inflating: datasets/dataset_coco_3/train/train_202_png_jpg.rf.5eaf4db329480122c3bca970b6cc5993.jpg
#   inflating: datasets/dataset_coco_3/train/train_202_png_jpg.rf.f165b37f291521262782f0a8c6d311c6.jpg
#   inflating: datasets/dataset_coco_3/train/train_203_png_jpg.rf.81d7f8dbadeea5a9e8a3261917d09aa3.jpg
#   inflating: datasets/dataset_coco_3/train/train_203_png_jpg.rf.86a483f83d8294a55ea87444ef297728.jpg
#   inflating: datasets/dataset_coco_3/train/train_203_png_jpg.rf.cfaf443b8c1c4e292439596801c48a66.jpg
#   inflating: datasets/dataset_coco_3/train/train_205_png_jpg.rf.2174d2700833603e22c483536e669b8b.jpg
#   inflating: datasets/dataset_coco_3/train/train_205_png_jpg.rf.6934a20776dc9a2aad4b6e564275d4c8.jpg
#   inflating: datasets/dataset_coco_3/train/train_205_png_jpg.rf.f1f070a2fec36479d1c6dc713eb175cc.jpg
#   inflating: datasets/dataset_coco_3/train/train_207_png_jpg.rf.18340d8570423f16eeb3ca3206efc831.jpg
#   inflating: datasets/dataset_coco_3/train/train_207_png_jpg.rf.4972c860533f39224cbd22f6fe904094.jpg
#   inflating: datasets/dataset_coco_3/train/train_207_png_jpg.rf.d673d439c358e1a24ae704ab39c04b8d.jpg
#   inflating: datasets/dataset_coco_3/train/train_209_png_jpg.rf.11533cd3cd3e0afbf3f383b18b5d26b2.jpg
#   inflating: datasets/dataset_coco_3/train/train_209_png_jpg.rf.18b743b28b5560af2fcc9bb6cd4f1c0c.jpg
#   inflating: datasets/dataset_coco_3/train/train_209_png_jpg.rf.6a38cb94d07005b264941bab6dc4f569.jpg
#   inflating: datasets/dataset_coco_3/train/train_20_png_jpg.rf.11feee0e08223ebe3a09e1e43e5cf9a8.jpg
#   inflating: datasets/dataset_coco_3/train/train_20_png_jpg.rf.29ede63179d8a309fdf217e08d80daad.jpg
#   inflating: datasets/dataset_coco_3/train/train_20_png_jpg.rf.2bd4534e33c9f116d1251c5ce41d1e47.jpg
#   inflating: datasets/dataset_coco_3/train/train_20_png_jpg.rf.4ccc615750c1b0936462acf8e614671c.jpg
#   inflating: datasets/dataset_coco_3/train/train_20_png_jpg.rf.df4cff2b4f2c6b334fce101fbc6d6a33.jpg
#   inflating: datasets/dataset_coco_3/train/train_20_png_jpg.rf.e1b65e1063dacce623c139d6ff0f0413.jpg
#   inflating: datasets/dataset_coco_3/train/train_211_png_jpg.rf.3791eae7953e4a9ee5cd8fffb760c693.jpg
#   inflating: datasets/dataset_coco_3/train/train_211_png_jpg.rf.80e21bffa09c94be5a19c1603c778b1a.jpg
#   inflating: datasets/dataset_coco_3/train/train_211_png_jpg.rf.aeb05780bace66f4e9ebb79a50d8f207.jpg
#   inflating: datasets/dataset_coco_3/train/train_212_png_jpg.rf.cb6e514aa28c2d5d9c3bb0de7ce240a7.jpg
#   inflating: datasets/dataset_coco_3/train/train_212_png_jpg.rf.f0c7a5b75c77d5144420dd05d81ec0f4.jpg
#   inflating: datasets/dataset_coco_3/train/train_212_png_jpg.rf.f832b1aa29d2b23e0de37b5abbf926e2.jpg
#   inflating: datasets/dataset_coco_3/train/train_214_png_jpg.rf.3193ade001f140f8294b8b42e4ac908e.jpg
#   inflating: datasets/dataset_coco_3/train/train_214_png_jpg.rf.523779cc52be490ffe487c0570da2e11.jpg
#   inflating: datasets/dataset_coco_3/train/train_214_png_jpg.rf.59a4ebe35483af5e45ef941d6cb122dc.jpg
#   inflating: datasets/dataset_coco_3/train/train_215_png_jpg.rf.4aaf13869d41b7356c0a781a439a8242.jpg
#   inflating: datasets/dataset_coco_3/train/train_215_png_jpg.rf.9a047a775e9c5324ec736def13ed0188.jpg
#   inflating: datasets/dataset_coco_3/train/train_215_png_jpg.rf.cf3ff88859d498224aea6ca06e31c161.jpg
#   inflating: datasets/dataset_coco_3/train/train_216_png_jpg.rf.7b3f1d689765a3e377476207b6807c0a.jpg
#   inflating: datasets/dataset_coco_3/train/train_216_png_jpg.rf.d8f95f8c3cbc45bd3185d57488cbc302.jpg
#   inflating: datasets/dataset_coco_3/train/train_216_png_jpg.rf.e11e94c640edf9dcf87e182954327df7.jpg
#   inflating: datasets/dataset_coco_3/train/train_218_png_jpg.rf.29fcb15534dca688e14ac44ba0065986.jpg
#   inflating: datasets/dataset_coco_3/train/train_218_png_jpg.rf.2e0eb1f86be3dd00d0a7c978b3f9f3d1.jpg
#   inflating: datasets/dataset_coco_3/train/train_218_png_jpg.rf.8564a2a46568578a2fadadbc1d35e20c.jpg
#   inflating: datasets/dataset_coco_3/train/train_219_png_jpg.rf.527591615c45d7bb56a275eaf11f14d9.jpg
#   inflating: datasets/dataset_coco_3/train/train_219_png_jpg.rf.c19aac33cd4feaddfa0bee92cf3d06a1.jpg
#   inflating: datasets/dataset_coco_3/train/train_219_png_jpg.rf.ec093837478c3f518cc38dadcbcc511b.jpg
#   inflating: datasets/dataset_coco_3/train/train_21_png_jpg.rf.88716fc5417f4d224e9dbb009a4ce0ff.jpg
#   inflating: datasets/dataset_coco_3/train/train_21_png_jpg.rf.a71b42cd230edc51bb938f9193e998d1.jpg
#   inflating: datasets/dataset_coco_3/train/train_21_png_jpg.rf.f1a77c69f0c82c89e42c3fcf8ca155f1.jpg
#   inflating: datasets/dataset_coco_3/train/train_220_png_jpg.rf.361b60e4aed31b34c8bcb7eb6488312d.jpg
#   inflating: datasets/dataset_coco_3/train/train_220_png_jpg.rf.8c6a41e9c76cfe7a4d39a809831d463d.jpg
#   inflating: datasets/dataset_coco_3/train/train_220_png_jpg.rf.dae9f83da2818d022b164ff108672b7d.jpg
#   inflating: datasets/dataset_coco_3/train/train_221_png_jpg.rf.50b0e6092a5b19e7c05676529b059df4.jpg
#   inflating: datasets/dataset_coco_3/train/train_221_png_jpg.rf.ab485c59b7d2ddcc122e6feda7b3be3f.jpg
#   inflating: datasets/dataset_coco_3/train/train_221_png_jpg.rf.ec7d738b33190e28ff176945fd53d3e4.jpg
#   inflating: datasets/dataset_coco_3/train/train_223_png_jpg.rf.9885a472dfb86e1af5a267ce6d1bbc01.jpg
#   inflating: datasets/dataset_coco_3/train/train_223_png_jpg.rf.ba242c242ab6d5beaced369a27447317.jpg
#   inflating: datasets/dataset_coco_3/train/train_223_png_jpg.rf.f14fc595fb93cc00ce9ef9c3dc9a9595.jpg
#   inflating: datasets/dataset_coco_3/train/train_227_png_jpg.rf.a801edd2695ba3e3fa9f97ccc0c21cad.jpg
#   inflating: datasets/dataset_coco_3/train/train_227_png_jpg.rf.ad3d9db9677e508ff6203efbaf1b4c64.jpg
#   inflating: datasets/dataset_coco_3/train/train_227_png_jpg.rf.ffa79a83e039a8add37ea4736aaf31e0.jpg
#   inflating: datasets/dataset_coco_3/train/train_229_png_jpg.rf.0c89d27b200bce003f454026d9a0e6f1.jpg
#   inflating: datasets/dataset_coco_3/train/train_229_png_jpg.rf.580f86e8cd07ef5a00e8d04fb906ff0f.jpg
#   inflating: datasets/dataset_coco_3/train/train_229_png_jpg.rf.b762ada4b7240fa64e503b9910e53a34.jpg
#   inflating: datasets/dataset_coco_3/train/train_230_png_jpg.rf.250e89093b782f76f48e6483c80aa668.jpg
#   inflating: datasets/dataset_coco_3/train/train_230_png_jpg.rf.6e65ef0668d0760addac55f4e31811b1.jpg
#   inflating: datasets/dataset_coco_3/train/train_230_png_jpg.rf.e090c433d218d95d351ee5bdab8b2f16.jpg
#   inflating: datasets/dataset_coco_3/train/train_231_png_jpg.rf.1e77918caaef0974efc260e11ce33d2d.jpg
#   inflating: datasets/dataset_coco_3/train/train_231_png_jpg.rf.8dfcceb39ec63ecb03fbf97631e8503b.jpg
#   inflating: datasets/dataset_coco_3/train/train_231_png_jpg.rf.b3d7d5db8a6ee902eee6071a0e4fbba2.jpg
#   inflating: datasets/dataset_coco_3/train/train_232_png_jpg.rf.60780852e4f188aa8e3e4d5a4dd30916.jpg
#   inflating: datasets/dataset_coco_3/train/train_232_png_jpg.rf.b422ad6d9020f0ca3130dd9ed81b753e.jpg
#   inflating: datasets/dataset_coco_3/train/train_232_png_jpg.rf.dc0a2e4e6f8d9518c39501226c26d201.jpg
#   inflating: datasets/dataset_coco_3/train/train_233_png_jpg.rf.62a39c53b6c9a0d2711e5d6f5a7b030b.jpg
#   inflating: datasets/dataset_coco_3/train/train_233_png_jpg.rf.b6e61b63ea7953ce767b0a6291954dda.jpg
#   inflating: datasets/dataset_coco_3/train/train_233_png_jpg.rf.e5fd7c60fb960b0c6f1d7ca6b0db03cb.jpg
#   inflating: datasets/dataset_coco_3/train/train_234_png_jpg.rf.273ee33d3bc085d9c572a3ba8a373690.jpg
#   inflating: datasets/dataset_coco_3/train/train_234_png_jpg.rf.a1936a870712494d43a37843ee3b8444.jpg
#   inflating: datasets/dataset_coco_3/train/train_234_png_jpg.rf.e6c30bb1c69edf40272582668b1a5db4.jpg
#   inflating: datasets/dataset_coco_3/train/train_235_png_jpg.rf.308d9078e29e9751364122929eefbfa1.jpg
#   inflating: datasets/dataset_coco_3/train/train_235_png_jpg.rf.54dbf1364903ebbc737627a4623ee9c7.jpg
#   inflating: datasets/dataset_coco_3/train/train_235_png_jpg.rf.617fceff3398436ae22b8a96f949ebdc.jpg
#   inflating: datasets/dataset_coco_3/train/train_237_png_jpg.rf.703c37c74b83a717111527291934ba5d.jpg
#   inflating: datasets/dataset_coco_3/train/train_237_png_jpg.rf.b0eeaa3e445e5ae9db9bea770fb1906b.jpg
#   inflating: datasets/dataset_coco_3/train/train_237_png_jpg.rf.e04f4cca5acd348b886712d2e1dff0dd.jpg
#   inflating: datasets/dataset_coco_3/train/train_238_png_jpg.rf.5c7a0075357e8ab454d1e47152b92297.jpg
#   inflating: datasets/dataset_coco_3/train/train_238_png_jpg.rf.91fff533a3f3af98ff23b4bee66b5acf.jpg
#   inflating: datasets/dataset_coco_3/train/train_238_png_jpg.rf.b2fa35c7f0e8a0a048449b6d02335563.jpg
#   inflating: datasets/dataset_coco_3/train/train_239_png_jpg.rf.8f4428207653cb3ddd17a69723162549.jpg
#   inflating: datasets/dataset_coco_3/train/train_239_png_jpg.rf.a2b259fb68d570f7114e7f3b60fff623.jpg
#   inflating: datasets/dataset_coco_3/train/train_239_png_jpg.rf.ef01be9e70f9de6ff8d2ab29fbd43aed.jpg
#   inflating: datasets/dataset_coco_3/train/train_23_png_jpg.rf.0c12747751cb3fb82a694cb6a5858af4.jpg
#   inflating: datasets/dataset_coco_3/train/train_23_png_jpg.rf.3f230a6802520096e55388bea56120b8.jpg
#   inflating: datasets/dataset_coco_3/train/train_23_png_jpg.rf.653b2143777a41711bfaa53327c3ea06.jpg
#   inflating: datasets/dataset_coco_3/train/train_240_png_jpg.rf.23aed153c5508ef092b5c5a61a4353c8.jpg
#   inflating: datasets/dataset_coco_3/train/train_240_png_jpg.rf.6da1e4f1985c69c78ba7cff8d65eefff.jpg
#   inflating: datasets/dataset_coco_3/train/train_240_png_jpg.rf.b09bcb160238fc8d64767d878adbd226.jpg
#   inflating: datasets/dataset_coco_3/train/train_241_png_jpg.rf.22569d3883e8adff6bf548cb3dc3041b.jpg
#   inflating: datasets/dataset_coco_3/train/train_241_png_jpg.rf.53f437afa1770e71f33218d10741a866.jpg
#   inflating: datasets/dataset_coco_3/train/train_241_png_jpg.rf.d2da96ab70522613f75a6487ea108dab.jpg
#   inflating: datasets/dataset_coco_3/train/train_244_png_jpg.rf.0b5e707d142185b262b95bdc8f24e576.jpg
#   inflating: datasets/dataset_coco_3/train/train_244_png_jpg.rf.80bcb7abe46f7905a2338028c117e32b.jpg
#   inflating: datasets/dataset_coco_3/train/train_244_png_jpg.rf.f777c7efe1f3aa6528c3edec47238513.jpg
#   inflating: datasets/dataset_coco_3/train/train_245_png_jpg.rf.0fa83b2fdefe89406be6cef223360de7.jpg
#   inflating: datasets/dataset_coco_3/train/train_245_png_jpg.rf.85a6a325e6e3f2e332ced1fa4ea63307.jpg
#   inflating: datasets/dataset_coco_3/train/train_245_png_jpg.rf.bcb4c86263caeb3596c09d3335b8ea50.jpg
# ...
#   inflating: datasets/dataset_coco_3/valid/train_152_png_jpg.rf.9f6e702a63dd251d06cfb865840206ea.jpg
#   inflating: datasets/dataset_coco_3/valid/train_155_png_jpg.rf.f5d5a876d735fa1d6573a8cd0a1ce6d3.jpg
#   inflating: datasets/dataset_coco_3/valid/train_156_png_jpg.rf.31f89ce137c33389fd1419b146e5446b.jpg
#   inflating: datasets/dataset_coco_3/valid/train_176_png_jpg.rf.cb7726028d714c81ee8a902cb2b45486.jpg
#   inflating: datasets/dataset_coco_3/valid/train_181_png_jpg.rf.aff7b010eb726369a0a708599612ffe6.jpg
#   inflating: datasets/dataset_coco_3/valid/train_183_png_jpg.rf.7022be10ff356babe84e58dda78f9656.jpg
#   inflating: datasets/dataset_coco_3/valid/train_185_png_jpg.rf.87834e821fd3d205404c319d720481cc.jpg
#   inflating: datasets/dataset_coco_3/valid/train_194_png_jpg.rf.25d88a3aa971a69e9d458dbe7ffd452f.jpg
#   inflating: datasets/dataset_coco_3/valid/train_195_png_jpg.rf.f959abe433741531e993396cf7dc255e.jpg
#   inflating: datasets/dataset_coco_3/valid/train_1_png_jpg.rf.52b3012bca70a5032be44e9757c5d023.jpg
#   inflating: datasets/dataset_coco_3/valid/train_1_png_jpg.rf.e7c5b4abb96d88f7c5182ce7b174bbf7.jpg
#   inflating: datasets/dataset_coco_3/valid/train_206_png_jpg.rf.166f28afd8233a8eb1b6de3b2841f5bf.jpg
#   inflating: datasets/dataset_coco_3/valid/train_208_png_jpg.rf.7fba62e1af8ec4213391064f093df89d.jpg
#   inflating: datasets/dataset_coco_3/valid/train_210_png_jpg.rf.efd7c5b3291720f6fb5d071cf2bde7ce.jpg
#   inflating: datasets/dataset_coco_3/valid/train_217_png_jpg.rf.0cc9d7d9b6519723f403beecb1fc1d05.jpg
#   inflating: datasets/dataset_coco_3/valid/train_21_png_jpg.rf.7ecbc02eb6a80fc8a7e10b02d1c17ec4.jpg
#   inflating: datasets/dataset_coco_3/valid/train_224_png_jpg.rf.59889d416d296f91c1e5110d451b4136.jpg
#   inflating: datasets/dataset_coco_3/valid/train_228_png_jpg.rf.b742ccad783c1f5c93bf2af60edd5530.jpg
#   inflating: datasets/dataset_coco_3/valid/train_22_png_jpg.rf.1e32c0a977707c9912a886e97a1f7d3a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_22_png_jpg.rf.f8d0a58d4bc721d399eda5e89ca6033e.jpg
#   inflating: datasets/dataset_coco_3/valid/train_236_png_jpg.rf.c942928cae68a7d6a7bf77fdb23b7c0a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_242_png_jpg.rf.818824e87d2ebcbee97c5062348ffd57.jpg
#   inflating: datasets/dataset_coco_3/valid/train_24_png_jpg.rf.78776d0c424d07d20d37910525bd57eb.jpg
#   inflating: datasets/dataset_coco_3/valid/train_24_png_jpg.rf.e2fc81cbfaf91cf4e25b41a92307d2ba.jpg
#   inflating: datasets/dataset_coco_3/valid/train_250_png_jpg.rf.5735a14b9a34bee6a7502a6a52d41f4a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_254_png_jpg.rf.655d3b38ed53a12a5e7a5ee70429041d.jpg
#   inflating: datasets/dataset_coco_3/valid/train_256_png_jpg.rf.fcd7e2c92d84aa33a2ffb19888c00060.jpg
#   inflating: datasets/dataset_coco_3/valid/train_257_png_jpg.rf.8f1c03bd5779b9fcb84de4e1c3c6f457.jpg
#   inflating: datasets/dataset_coco_3/valid/train_25_png_jpg.rf.745d29dcc7b08a43dd9d122b97c2b2e9.jpg
#   inflating: datasets/dataset_coco_3/valid/train_262_png_jpg.rf.f9b4b030a0a535d302c262fc3ab3175d.jpg
#   inflating: datasets/dataset_coco_3/valid/train_267_png_jpg.rf.a1403092d6aaf508f329166e25a47200.jpg
#   inflating: datasets/dataset_coco_3/valid/train_271_png_jpg.rf.02cb43df701240083ce3f4bdf9f8d80a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_273_png_jpg.rf.1753e50f54ffb042ebb779efdbcfe7c1.jpg
#   inflating: datasets/dataset_coco_3/valid/train_274_png_jpg.rf.013773ad0bac88f8750d4e052ec395c5.jpg
#   inflating: datasets/dataset_coco_3/valid/train_281_png_jpg.rf.bef7226e996536a6d0710cf0884c0718.jpg
#   inflating: datasets/dataset_coco_3/valid/train_286_png_jpg.rf.a91a041438cebfba6ee2979ad59980be.jpg
#   inflating: datasets/dataset_coco_3/valid/train_288_png_jpg.rf.db6b1c633a909da2fb478e6a7c757d2a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_298_png_jpg.rf.66022cb9031b999ce6f8e8a45673accb.jpg
#   inflating: datasets/dataset_coco_3/valid/train_2_png_jpg.rf.d23582205d2e18b2a29bb3e887c17b62.jpg
#   inflating: datasets/dataset_coco_3/valid/train_303_png_jpg.rf.d75718d2d08920ae3908396a46105fe2.jpg
#   inflating: datasets/dataset_coco_3/valid/train_305_png_jpg.rf.ccd6ab459b53bd48b1d84727fea7803c.jpg
#   inflating: datasets/dataset_coco_3/valid/train_30_png_jpg.rf.1e6dde3a861a9d8a92d4ca3b1bfa57d9.jpg
#   inflating: datasets/dataset_coco_3/valid/train_30_png_jpg.rf.b85612c9df9f65fdfe6b9c24cbb12bde.jpg
#   inflating: datasets/dataset_coco_3/valid/train_310_png_jpg.rf.3dcaad886313da3afd3dedf031f1c4d7.jpg
#   inflating: datasets/dataset_coco_3/valid/train_313_png_jpg.rf.225e015c62ff18ca934a063fd9d1947e.jpg
#   inflating: datasets/dataset_coco_3/valid/train_322_png_jpg.rf.9d7b4795850914db6e59fdacbd5609e2.jpg
#   inflating: datasets/dataset_coco_3/valid/train_330_png_jpg.rf.204991d37eea903f8db3b5d637e21ee8.jpg
#   inflating: datasets/dataset_coco_3/valid/train_338_png_jpg.rf.33a433eec441d6c8378967e892e42c9b.jpg
#   inflating: datasets/dataset_coco_3/valid/train_340_png_jpg.rf.e2ee2c10236085f5850cb5464c41afd3.jpg
#   inflating: datasets/dataset_coco_3/valid/train_345_png_jpg.rf.adbd064b73195a91dce3a051bcbff943.jpg
#   inflating: datasets/dataset_coco_3/valid/train_347_png_jpg.rf.057889d2be681744500a7ae9294e8714.jpg
#   inflating: datasets/dataset_coco_3/valid/train_349_png_jpg.rf.f32be14897ea05eef441376a20e835fd.jpg
#   inflating: datasets/dataset_coco_3/valid/train_34_png_jpg.rf.9fe1935f6420a3ee65a707610c8463af.jpg
#   inflating: datasets/dataset_coco_3/valid/train_351_png_jpg.rf.ebd2c3f41ee27075819c0bd56ef2d5f4.jpg
#   inflating: datasets/dataset_coco_3/valid/train_352_png_jpg.rf.c3aa540ee49220c807c0eb4066db2411.jpg
#   inflating: datasets/dataset_coco_3/valid/train_357_png_jpg.rf.9d71478b7451a198d475a10360873e96.jpg
#   inflating: datasets/dataset_coco_3/valid/train_358_png_jpg.rf.bbb464c846fbb89a5fe1da70e30e9a06.jpg
#   inflating: datasets/dataset_coco_3/valid/train_361_png_jpg.rf.a668539522f039f2fa8c48c305d30727.jpg
#   inflating: datasets/dataset_coco_3/valid/train_368_png_jpg.rf.3f7224ff5a7b9226663899cb4a1e482c.jpg
#   inflating: datasets/dataset_coco_3/valid/train_372_png_jpg.rf.becb78d931ff2ed7f4a8278ac745aa72.jpg
#   inflating: datasets/dataset_coco_3/valid/train_373_png_jpg.rf.ec9dd50673b3b5b3a48b67ee35f7aa82.jpg
#   inflating: datasets/dataset_coco_3/valid/train_37_png_jpg.rf.16966a8382b40bb1c7aacbda79103e61.jpg
#   inflating: datasets/dataset_coco_3/valid/train_382_png_jpg.rf.dd218ecd2add36721c53800792314421.jpg
#   inflating: datasets/dataset_coco_3/valid/train_383_png_jpg.rf.15c148a2ca2feaf54ff726c31f0f19cb.jpg
#   inflating: datasets/dataset_coco_3/valid/train_387_png_jpg.rf.d7e95c98f1420dd18c77122897b1c934.jpg
#   inflating: datasets/dataset_coco_3/valid/train_388_png_jpg.rf.c972f9b37ee9833cd56c06d09a87478d.jpg
#   inflating: datasets/dataset_coco_3/valid/train_38_png_jpg.rf.aa52e27b3c844f585f76e0db64d37f2a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_392_png_jpg.rf.6186a4a08d5d23b9c3ea8e6bb3101834.jpg
#   inflating: datasets/dataset_coco_3/valid/train_396_png_jpg.rf.12ae67288fd57be1c31c8d647bda9b06.jpg
#   inflating: datasets/dataset_coco_3/valid/train_398_png_jpg.rf.30ef5062a86b00f6afb3e20ac940e488.jpg
#   inflating: datasets/dataset_coco_3/valid/train_3_png_jpg.rf.212b63b00dd66ef97465ff4d760a2e2a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_407_png_jpg.rf.2de643cd7a6f6b31e626c5cfbb136c41.jpg
#   inflating: datasets/dataset_coco_3/valid/train_40_png_jpg.rf.8706cb7f1689266cde1b8ffb9f51c8dc.jpg
#   inflating: datasets/dataset_coco_3/valid/train_410_png_jpg.rf.aea4fc7063d7cedc529679c3e569c5ef.jpg
#   inflating: datasets/dataset_coco_3/valid/train_419_png_jpg.rf.f1acf2b5a484ba7a247ac7aabbdad9a7.jpg
#   inflating: datasets/dataset_coco_3/valid/train_41_png_jpg.rf.44b9b516440e6a0c19f26452af4af402.jpg
#   inflating: datasets/dataset_coco_3/valid/train_432_png_jpg.rf.b3beb3a35dc25e82bff99c9f8f7ecbe6.jpg
#   inflating: datasets/dataset_coco_3/valid/train_434_png_jpg.rf.db11d273c6d0513b3cd9dbb071fd1416.jpg
#   inflating: datasets/dataset_coco_3/valid/train_435_png_jpg.rf.66764966a4069273db4e21c1468433f1.jpg
#   inflating: datasets/dataset_coco_3/valid/train_43_png_jpg.rf.01392316b7311f28cb1d4300816f8c4e.jpg
#   inflating: datasets/dataset_coco_3/valid/train_43_png_jpg.rf.47d1f4b86884eb211415ab64a0bae250.jpg
#   inflating: datasets/dataset_coco_3/valid/train_440_png_jpg.rf.16ed582bb21c32720a8a9df823c95740.jpg
#   inflating: datasets/dataset_coco_3/valid/train_44_png_jpg.rf.5161e279291a16c1c2475e695a8d9086.jpg
#   inflating: datasets/dataset_coco_3/valid/train_459_png_jpg.rf.464153e046ad74cf2fcb49aebc854367.jpg
#   inflating: datasets/dataset_coco_3/valid/train_45_png_jpg.rf.0297aaadadba7808eae92a51ad642c1f.jpg
#   inflating: datasets/dataset_coco_3/valid/train_462_png_jpg.rf.84775acd8e68e600f42a6afbc3b43833.jpg
#   inflating: datasets/dataset_coco_3/valid/train_474_png_jpg.rf.ecb9b55370b184e0eda85c5e203ad3ec.jpg
#   inflating: datasets/dataset_coco_3/valid/train_477_png_jpg.rf.a9823376bcc5293d348d4f902a0c4b66.jpg
#   inflating: datasets/dataset_coco_3/valid/train_47_png_jpg.rf.7e320f5ddaa497c285d5b3a5b3c7d8c4.jpg
#   inflating: datasets/dataset_coco_3/valid/train_481_png_jpg.rf.6e962a1111be581dba8108c03565d5eb.jpg
#   inflating: datasets/dataset_coco_3/valid/train_483_png_jpg.rf.87c44bbefa081794687a31e23c09e4ee.jpg
#   inflating: datasets/dataset_coco_3/valid/train_486_png_jpg.rf.b9161396ed9145c22db78d0702cd9cfb.jpg
#   inflating: datasets/dataset_coco_3/valid/train_498_png_jpg.rf.a40a1980b5a0aad4f2720c3daaeee803.jpg
#   inflating: datasets/dataset_coco_3/valid/train_503_png_jpg.rf.3ae6646aa3f47e795d6b4fca70fe6c9c.jpg
#   inflating: datasets/dataset_coco_3/valid/train_504_png_jpg.rf.ea754fc2dd14431909cdbb7ca63c2cc5.jpg
#   inflating: datasets/dataset_coco_3/valid/train_505_png_jpg.rf.49c8ed8d8b8b1af7bfa51762c675da58.jpg
#   inflating: datasets/dataset_coco_3/valid/train_51_png_jpg.rf.06469ad05bf6f19d39aba2ddd711d248.jpg
#   inflating: datasets/dataset_coco_3/valid/train_523_png_jpg.rf.b21b8df2357a2e1ddfbbfe1e55b0cd42.jpg
#   inflating: datasets/dataset_coco_3/valid/train_524_png_jpg.rf.a8081256ba032d03efe049ff6fa1a299.jpg
#   inflating: datasets/dataset_coco_3/valid/train_526_png_jpg.rf.06a7e088ac194190b4d7737a59c511d3.jpg
#   inflating: datasets/dataset_coco_3/valid/train_528_png_jpg.rf.5b2ebb9baffd4199ba13cd05c77366fb.jpg
#   inflating: datasets/dataset_coco_3/valid/train_52_png_jpg.rf.10fd331126342a655c2cec4e8d608c7a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_539_png_jpg.rf.fa0597a8fec54003d891994c0c34e2ca.jpg
#   inflating: datasets/dataset_coco_3/valid/train_559_png_jpg.rf.de38b36e9cf9538a6a9425d89ba65a3c.jpg
#   inflating: datasets/dataset_coco_3/valid/train_564_png_jpg.rf.5413b43410bb78e45db388890fc90209.jpg
#   inflating: datasets/dataset_coco_3/valid/train_567_png_jpg.rf.605ff64bc155b69d8e48b092e23cc9fe.jpg
#   inflating: datasets/dataset_coco_3/valid/train_570_png_jpg.rf.804cf50bedd32d25070311c047105eda.jpg
#   inflating: datasets/dataset_coco_3/valid/train_572_png_jpg.rf.d42c7f838230c03fda72c06ceecda12a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_577_png_jpg.rf.163776830c893043554b676019a6b4b8.jpg
#   inflating: datasets/dataset_coco_3/valid/train_579_png_jpg.rf.195fc405356a9408e722897685cde905.jpg
#   inflating: datasets/dataset_coco_3/valid/train_581_png_jpg.rf.14904a7f2059c120863eef0c8371daaf.jpg
#   inflating: datasets/dataset_coco_3/valid/train_583_png_jpg.rf.0fde57b5ca3d1b780a988ff6b177c0ea.jpg
#   inflating: datasets/dataset_coco_3/valid/train_591_png_jpg.rf.2ee4f9488b945b7fb13ec4fd5a8326d1.jpg
#   inflating: datasets/dataset_coco_3/valid/train_592_png_jpg.rf.e31a04b13c7191443e4492fb0267a670.jpg
#   inflating: datasets/dataset_coco_3/valid/train_599_png_jpg.rf.d7b46b16feb2108f3e42a060f83f4fb4.jpg
#   inflating: datasets/dataset_coco_3/valid/train_59_png_jpg.rf.cd05b6a25f60bbe7dca7c7fb66bb9708.jpg
#   inflating: datasets/dataset_coco_3/valid/train_5_png_jpg.rf.4c59a88807162ae305d6155e3fbcc739.jpg
#   inflating: datasets/dataset_coco_3/valid/train_606_png_jpg.rf.42f7e711ba860cf122b4a15dd913fd5f.jpg
#   inflating: datasets/dataset_coco_3/valid/train_609_png_jpg.rf.6663584906c8058e5953b6102fa2f86b.jpg
#   inflating: datasets/dataset_coco_3/valid/train_60_png_jpg.rf.0b1e6d934b3a56e7e464bba807238c2a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_615_png_jpg.rf.a4725575bcaed406f8deeb84e0403a1c.jpg
#   inflating: datasets/dataset_coco_3/valid/train_616_png_jpg.rf.ae86ae954425d60a416c83e5c5cec960.jpg
#   inflating: datasets/dataset_coco_3/valid/train_61_png_jpg.rf.32207a77b770c1d0bd3bae8f78dceb8a.jpg
#   inflating: datasets/dataset_coco_3/valid/train_621_png_jpg.rf.7c9796e27fdce90972b989c00ce46d91.jpg
#   inflating: datasets/dataset_coco_3/valid/train_622_png_jpg.rf.2e42d291c994011b25b209a1de25ca68.jpg
#   inflating: datasets/dataset_coco_3/valid/train_626_png_jpg.rf.cb6b696bed546e76fbfdf9245ffd63b8.jpg
#   inflating: datasets/dataset_coco_3/valid/train_627_png_jpg.rf.f6c7a0eac991db9db37ef3167c0f3a2b.jpg
#   inflating: datasets/dataset_coco_3/valid/train_629_png_jpg.rf.4242eda266b987156f0609d9b7183fd3.jpg
#   inflating: datasets/dataset_coco_3/valid/train_62_png_jpg.rf.11286c11e0df34502476de7d9bb63ad0.jpg
#   inflating: datasets/dataset_coco_3/valid/train_636_png_jpg.rf.97ea50f95cb3f5fb4228764dcc8d832e.jpg
#   inflating: datasets/dataset_coco_3/valid/train_640_png_jpg.rf.9f769dbd0876c964b406ecfd72c70bc8.jpg
#   inflating: datasets/dataset_coco_3/valid/train_646_png_jpg.rf.8134808da3ac8504d408e7ca46634a32.jpg
#   inflating: datasets/dataset_coco_3/valid/train_648_png_jpg.rf.9217e1f43fffab0f5036be6e08c502b7.jpg
#   inflating: datasets/dataset_coco_3/valid/train_649_png_jpg.rf.778ae2f5d194fcaf959fb5b9d5f8cce5.jpg
#   inflating: datasets/dataset_coco_3/valid/train_650_png_jpg.rf.765dfc40ca2e8d8a30f245d825bbd12b.jpg
#   inflating: datasets/dataset_coco_3/valid/train_652_png_jpg.rf.7e76611dd7211af3b0fb35a81c741e73.jpg
#   inflating: datasets/dataset_coco_3/valid/train_661_png_jpg.rf.1e263e32403b4a0d6caa09f05246d139.jpg
#   inflating: datasets/dataset_coco_3/valid/train_665_png_jpg.rf.5bd96c7fe21e1888544588cd6d8194d9.jpg
#   inflating: datasets/dataset_coco_3/valid/train_678_png_jpg.rf.04d5673fc864aecf8d7b1b1f6a758aab.jpg
#   inflating: datasets/dataset_coco_3/valid/train_67_png_jpg.rf.5245a15529733bcc0ac7d9f70e33fcae.jpg
#   inflating: datasets/dataset_coco_3/valid/train_680_png_jpg.rf.768c26e7cfb410e086ff54188fd15f6d.jpg
#   inflating: datasets/dataset_coco_3/valid/train_687_png_jpg.rf.208a2a92544bc3293de8b949417ac405.jpg
#   inflating: datasets/dataset_coco_3/valid/train_86_png_jpg.rf.d446d49ca33e959338669ff13dc151c6.jpg
#   inflating: datasets/dataset_coco_3/valid/train_89_png_jpg.rf.843101f8603ac3762c0e92c17305b7c0.jpg
#   inflating: datasets/dataset_coco_3/valid/train_9_png_jpg.rf.8828690e9002d39498676b52309af86b.jpg
#   inflating: datasets/dataset_coco_3/valid/val_17_png_jpg.rf.bb47fb0a46be0c5ca651b37b64daf0a8.jpg
#   inflating: datasets/dataset_coco_3/valid/val_21_png_jpg.rf.31574ea822c64e6145225368db031cf9.jpg
#   inflating: datasets/dataset_coco_3/valid/val_26_png_jpg.rf.67b1c5038d791a03e82aba3e2b2f525d.jpg
#   inflating: datasets/dataset_coco_3/valid/val_32_png_jpg.rf.7a15c3294510f241942a68d5f5d5f394.jpg
#   inflating: datasets/dataset_coco_3/valid/val_37_png_jpg.rf.e400c78283f1a6f86e19d32e8ae021dd.jpg
#   inflating: datasets/dataset_coco_3/valid/val_3_png_jpg.rf.ea8d79c5acf02a1087c60d7c9529d988.jpg
#   inflating: datasets/dataset_coco_3/valid/val_41_png_jpg.rf.1193e2dba924922064a8be22dd6b52e3.jpg
#   inflating: datasets/dataset_coco_3/valid/val_47_png_jpg.rf.b56230bc7126c26614316ca4867126be.jpg
#   inflating: datasets/dataset_coco_3/valid/val_48_png_jpg.rf.b506633da24984d525bacc4c22453c70.jpg
#   inflating: datasets/dataset_coco_3/valid/_annotations.coco.json
#   inflating: datasets/dataset_coco_3/README.dataset.txt
#   inflating: datasets/dataset_coco_3/README.roboflow.txt

# %% [markdown]
# ## Funciones para la creación de los dataloaders

# %%
import torch, os, json
from torch.utils.data import Dataset
import numpy as np
from collections import defaultdict
from torchvision import ops
import matplotlib.patches as patches
from torchvision import transforms as T
from PIL import Image
import cv2
import copy
from pycocotools.cocoeval import COCOeval

# %%
# the dataset class
class CocoDataset(Dataset):
    def __init__(self, image_folder, annotations_file, width, height, transforms=None):

        self.transforms = transforms
        self.image_folder = image_folder
        self.annotations_file = annotations_file
        self.height = height
        self.width = width

        if not isinstance(self.image_folder, str):
            raise ValueError("image_folder should be a string")

        if not isinstance(annotations_file, str):
            raise ValueError("annotations_file should be a string")

        self.annotations_file = annotations_file
        self.image_folder = image_folder
        self.width = width
        self.height = height

        with open(annotations_file, "r") as f:
            self.annotations = json.load(f)

        self.image_ids = defaultdict(list)
        for i in self.annotations["images"]:
            self.image_ids[i["id"]] = i  # key = image_id

        self.annotation_ids = defaultdict(list)
        for i in self.annotations["annotations"]:
            self.annotation_ids[i["image_id"]].append(i)  # key = image_id

        self.cats_id2label = {}
        self.label_names = []

        first_label_id = self.annotations["categories"][0]["id"]
        if first_label_id == 0:
            for i in self.annotations["categories"][1:]:
                self.cats_id2label[i["id"]] = i["name"]
                self.label_names.append(i["name"])
        if first_label_id == 1:
            for i in self.annotations["categories"]:
                self.cats_id2label[i["id"]] = i["name"]
                self.label_names.append(i["name"])
        if first_label_id > 1:
            raise AssertionError(
                "Something went wrong in categories, check the annotation file!"
            )

    def get_total_classes_count(self):
        return len(self.cats_id2label)

    def get_classnames(self):
        return [v for k, v in self.cats_id2label.items()]

    def load_images_annotations(self, index):
        image_info = self.image_ids[index]
        image_path = os.path.join(self.image_folder, image_info["file_name"])

        image = cv2.imread(image_path)
        rimage = cv2.cvtColor(
            image, cv2.COLOR_BGR2RGB
        )  # .astype(np.float32) # convert BGR to RGB color format
        rimage = cv2.resize(rimage, (self.width, self.height))
        # rimage /= 255.0
        rimage = Image.fromarray(rimage)

        image_height, image_width = (
            image_info["height"],
            image_info["width"],
        )  # original height & width
        anno_info = self.annotation_ids[index]

        if len(anno_info) == 0:  # for negative images (Images without annotations)
            boxes = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros((0, 1), dtype=torch.int64)
            iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
            area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        else:
            boxes = []
            labels_id = []

            for ainfo in anno_info:
                xmin, ymin, w, h = ainfo["bbox"]
                xmax, ymax = xmin + w, ymin + h

                xmin_final = (xmin / image_width) * self.width
                xmax_final = (xmax / image_width) * self.width
                ymin_final = (ymin / image_height) * self.height
                ymax_final = (ymax / image_height) * self.height

                category_id = ainfo["category_id"]

                boxes.append([xmin_final, ymin_final, xmax_final, ymax_final])
                labels_id.append(category_id)

            boxes = torch.as_tensor(
                boxes, dtype=torch.float32
            )  # bounding box to tensor
            area = (boxes[:, 3] - boxes[:, 1]) * (
                boxes[:, 2] - boxes[:, 0]
            )  # area of the bounding boxes
            iscrowd = torch.zeros(
                (boxes.shape[0],), dtype=torch.int64
            )  # no crowd instances
            labels = torch.as_tensor(labels_id, dtype=torch.int64)  # labels to tensor

        # final `target` dictionary
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        image_id = torch.tensor([index])
        target["image_id"] = image_id

        return {
            "image": rimage,
            "height": image_height,
            "width": image_width,
            "target": target,
        }
    
    @staticmethod
    def transform_image_for_inference(image_path,width,height):
        
        image = cv2.imread(image_path)
        ori_h, ori_w, _ = image.shape
        
        oimage = copy.deepcopy(image)
        oimage = Image.fromarray(oimage)
        oimage = T.ToTensor()(oimage)
        
        rimage = cv2.cvtColor(
            image, cv2.COLOR_BGR2RGB
        )
        rimage = cv2.resize(rimage, (width,height))
        rimage = Image.fromarray(rimage)
        rimage = T.ToTensor()(rimage)
        # rimage = torch.unsqueeze(rimage, 0)
        
        transform_info = {'original_width':ori_w,
                          'original_height':ori_h,
                          'resized_width':width,
                          'resized_height':height,
                          'resized_image':rimage,
                          'original_image':oimage}
        
        return transform_info # this can directly go to model for inference

    @staticmethod
    def display_bbox(
        bboxes, fig, ax, classes=None, in_format="xyxy", color="y", line_width=3
    ):
        if type(bboxes) == np.ndarray:
            bboxes = torch.from_numpy(bboxes)
        if classes:
            assert len(bboxes) == len(classes)
        # convert boxes to xywh format
        bboxes = ops.box_convert(bboxes, in_fmt=in_format, out_fmt="xywh")
        c = 0
        for box in bboxes:
            x, y, w, h = box.numpy()
            # display bounding box
            rect = patches.Rectangle(
                (x, y), w, h, linewidth=line_width, edgecolor=color, facecolor="none"
            )
            ax.add_patch(rect)
            # display category
            if classes:
                if classes[c] == "pad":
                    continue
                ax.text(
                    x + 5, y + 20, classes[c], bbox=dict(facecolor="yellow", alpha=0.5)
                )
            c += 1

        return fig, ax

    def __getitem__(self, idx):

        sample = self.load_images_annotations(idx)
        image_resized = sample["image"]
        target = sample["target"]

        # apply the image transforms
        if self.transforms:
            sample = self.transforms(
                image=image_resized, bboxes=target["boxes"], labels=sample["labels"]
            )
            image_resized = sample["image"]
            target["boxes"] = torch.Tensor(sample["bboxes"])

        return T.ToTensor()(image_resized), target

    def __len__(self):
        return len(self.image_ids)

# %% [markdown]
# Cabe destacar que se utilizo una resolución 640x640 debido a limitaciones con la vRAM del equipo donde se realizo el entrenamiento. Sin embargo podría haber sido una buena opción aumentar la resolución.

# %%
def get_datasets(train_image_dir:str,
                 val_image_dir:str,
                 test_image_dir:str,
                 train_coco_json:str,
                 val_coco_json:str,
                 test_coco_json:str):

    train_ds = CocoDataset(
        image_folder=train_image_dir,
        annotations_file=train_coco_json,
        height=640,
        width=640,
    )

    val_ds = CocoDataset(
        image_folder=val_image_dir,
        annotations_file=val_coco_json,
        height=640,
        width=640,
    )
    
    test_ds = CocoDataset(
        image_folder=test_image_dir,
        annotations_file=test_coco_json,
        height=640,
        width=640,
    ) 

    return train_ds, val_ds, test_ds

# %% [markdown]
# ## Funciones para el entrenamiento del modelo

# %%
import time
from torch.utils.tensorboard import SummaryWriter
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import (
    FasterRCNN_ResNet50_FPN_Weights,
    FasterRCNN_ResNet50_FPN_V2_Weights,
)
from tqdm import tqdm
import gc
from pycocotools.coco import COCO
import matplotlib as plt

# %% [markdown]
# Se utilizo el modelo base de faster rcnn disponible en torchvision con la utilización de los pesos preentrenados

# %%
def create_model(num_classes,checkpoint=None,device='cpu'):
    """
    Create a model for object detection using the Faster R-CNN architecture.

    Parameters:
    - num_classes (int): The number of classes for object detection. (Total classes + 1 [for background class])
    - checkpoint (str) : checkpoint path for the pretrained custom model
    - device (str) : cpu / cuda
    Returns:
    - model (torchvision.models.detection.fasterrcnn_resnet50_fpn): The created model for object detection.
    """
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(
        pretrained=True,
        weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT,
        pretrained_backbone=True,
        #weights_backbone = 'ResNet50_Weights.DEFAULT',
    )
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    if checkpoint:
        checkpoint = torch.load(checkpoint, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
    else:
        model = model.to(device)
    return model

# %%
class InferFasterRCNN:
    def __init__(self, num_classes=None, classnames=[]):

        assert type(num_classes) != type(None), "Define number of classes"

        self.num_classes = num_classes  # total_class_no + 1 (for background)

        self.classnames = ["__background__"]
        self.classnames.extend(classnames)

        self.colors = np.random.uniform(0, 255, size=(len(self.classnames), 3))

        assert (
            len(self.classnames) == self.num_classes
        ), f"num_classes: {self.num_classes}, len(classnames): {len(self.classnames)}.\
            num_classes should be equal to count of actual classes in classnames list without background + 1"

    def load_model(self, checkpoint, device="cpu"):
        self.device = device
        self.model = create_model(
            self.num_classes, checkpoint=checkpoint, device=self.device
        )
        self.model = self.model.eval()

    def infer_image(self, transform_info ,detection_threshold=0.5, visualize=False):
        
        '''
        image : original unscaled image
        '''
        
        display_unscaled = True
        h_ratio = transform_info['original_height']/transform_info['resized_height']
        w_ratio = transform_info['original_width']/transform_info['resized_width']
        
        orig_image = transform_info['resized_image']
        orig_image = orig_image.cpu().numpy()
        orig_image = np.transpose(orig_image, (1, 2, 0))
        orig_image = np.ascontiguousarray(orig_image, dtype=np.float32)
        image = torch.unsqueeze(transform_info['resized_image'], 0)

        with torch.no_grad():
            self.model = self.model.to(self.device)
            outputs = self.model(image.to(self.device))

        # load all detection to CPU for further operations
        outputs = [{k: v.to("cpu") for k, v in t.items()} for t in outputs]

        results = {}
        _f_boxes,_f_scores,_f_labels = [],[],[]
        
        # carry further only if there are detected boxes
        if len(outputs[0]["boxes"]) != 0:
            boxes = outputs[0]["boxes"].data.numpy() # xyxy
            scores = outputs[0]["scores"].data.numpy()
            labels = outputs[0]["labels"].cpu().numpy()
            
            # filter out boxes according to `detection_threshold`
            for i in range(len(boxes)):
                if scores[i] >= detection_threshold:
                    _f_boxes.append(boxes[i])
                    _f_labels.append(labels[i])
                    _f_scores.append(scores[i])
            
            boxes,labels,scores = _f_boxes,_f_labels,_f_scores
            #boxes = boxes[scores >= detection_threshold].astype(np.int32)
            draw_boxes = boxes.copy()
            
            # get all the predicited class names
            pred_classes = [
                self.classnames[i] for i in labels
            ]
            
            results['unscaled_boxes'] = [[i[0]*w_ratio, i[1]*h_ratio, i[2]*w_ratio, i[3]*h_ratio] for i in boxes] # in original image size
            results['scaled_boxes'] = boxes # in resize image size
            results['scores'] = scores
            results['pred_classes'] = pred_classes
            results['labels'] = labels

            if not display_unscaled:
                # draw the bounding boxes and write the class name on top of it
                for j, box in enumerate(draw_boxes):
                    class_name = pred_classes[j]
                    color = self.colors[self.classnames.index(class_name)]
                    cv2.rectangle(
                        orig_image,
                        (int(box[0]), int(box[1])),
                        (int(box[2]), int(box[3])),
                        color,
                        2,
                    )
                    cv2.putText(
                        orig_image,
                        class_name,
                        (int(box[0]), int(box[1] - 5)),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.7,
                        color,
                        2,
                        lineType=cv2.LINE_AA,
                    )

                if visualize:
                    plt.figure(figsize=(10, 10))
                    plt.imshow(orig_image[:,:,::-1])
                    plt.show()
            
            else:
                # draw the bounding boxes and write the class name on top of it
                draw_boxes_scaled = results['unscaled_boxes']
                scaled_orig_image = transform_info['original_image']
                scaled_orig_image = scaled_orig_image.cpu().numpy()
                scaled_orig_image = np.transpose(scaled_orig_image, (1, 2, 0))
                scaled_orig_image = np.ascontiguousarray(scaled_orig_image, dtype=np.float32)
                
                for j, box in enumerate(draw_boxes_scaled):
                    class_name = pred_classes[j]
                    color = self.colors[self.classnames.index(class_name)]
                    cv2.rectangle(
                        scaled_orig_image,
                        (int(box[0]), int(box[1])),
                        (int(box[2]), int(box[3])),
                        color,
                        2,
                    )
                    cv2.putText(
                        scaled_orig_image,
                        class_name,
                        (int(box[0]), int(box[1] - 5)),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.7,
                        color,
                        2,
                        lineType=cv2.LINE_AA,
                    )

                if visualize:
                    plt.figure(figsize=(10, 10))
                    plt.imshow(scaled_orig_image)  # [:,:,::-1])
                    plt.show()

        return results

    def infer_image_path(self, image_path, detection_threshold=0.5, visualize=False):

        image = cv2.imread(image_path)
        orig_image = image.copy()

        # BGR to RGB
        image = cv2.cvtColor(orig_image, cv2.COLOR_BGR2RGB).astype(np.float32)
        # make the pixel range between 0 and 1
        image /= 255.0
        # bring color channels to front
        image = np.transpose(image, (2, 0, 1)).astype(np.float32)
        # convert to tensor
        image = torch.tensor(image, dtype=torch.float).cpu()

        # add batch dimension
        image = torch.unsqueeze(image, 0)
        with torch.no_grad():
            self.model = self.model.to(self.device)
            outputs = self.model(image.to(self.device))

        # load all detection to CPU for further operations
        outputs = [{k: v.to("cpu") for k, v in t.items()} for t in outputs]

        
        # carry further only if there are detected boxes
        if len(outputs[0]["boxes"]) != 0:
            boxes = outputs[0]["boxes"].data.numpy()
            scores = outputs[0]["scores"].data.numpy()

            # filter out boxes according to `detection_threshold`
            boxes = boxes[scores >= detection_threshold].astype(np.int32)
            draw_boxes = boxes.copy()

            # get all the predicited class names
            pred_classes = [
                self.classnames[i] for i in outputs[0]["labels"].cpu().numpy()
            ]

            # draw the bounding boxes and write the class name on top of it
            for j, box in enumerate(draw_boxes):
                class_name = pred_classes[j]
                color = self.colors[self.classnames.index(class_name)]
                cv2.rectangle(
                    orig_image,
                    (int(box[0]), int(box[1])),
                    (int(box[2]), int(box[3])),
                    color,
                    2,
                )
                cv2.putText(
                    orig_image,
                    class_name,
                    (int(box[0]), int(box[1] - 5)),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.7,
                    color,
                    2,
                    lineType=cv2.LINE_AA,
                )

            if visualize:
                plt.figure(figsize=(10, 10))
                plt.imshow(orig_image[:, :, ::-1])
                plt.show()

        return outputs
    
    
    def draw_bounding_boxes(self,image, bboxes, class_labels, figsize=(12,12)):
        class_labels = class_labels.cpu().numpy()
        bboxes = bboxes.cpu().numpy()
        for j, box in enumerate(bboxes):
            label = class_labels[j]
            color = self.colors[label]
            cv2.rectangle(
                    image,
                    (int(box[0]), int(box[1])),
                    (int(box[2]), int(box[3])),
                    (0,200,0),
                    1,
                )
            cv2.putText(
                image,
                self.classnames[int(label)],
                (int(box[0] + 15), int(box[1] + 15)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.5,
                (0,200,0),
                2,
                lineType=cv2.LINE_AA,
            )
        
        plt.figure(figsize=figsize)
        plt.imshow(image)
        plt.show()

# %%
class SaveBestModel:
    """
    Class to save the best model while training. If the current epoch's 
    validation loss is less than the previous least less, then save the
    model state.
    """
    def __init__(
        self, best_valid_loss=float('inf'), output_dir = 'weight_outputs',
    ):
        self.best_valid_loss = best_valid_loss
    
        os.makedirs(output_dir,exist_ok=True)
        
        self.output_dir = output_dir
        
    def __call__(
        self, current_valid_loss, 
        epoch, model, optimizer
    ):
        self.model_save_path = f'{self.output_dir}/best_model.pth'
        if current_valid_loss < self.best_valid_loss:
            self.best_valid_loss = current_valid_loss
            print(f"\nBest validation loss: {self.best_valid_loss}")
            print(f"\nSaving best model for epoch: {epoch+1}\n")
            torch.save({
                'epoch': epoch+1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                }, self.model_save_path)

# %%
@torch.inference_mode() #desactivar el cálculo de gradientes, optimizaciones y la creación de gráficos computacionales
def val_one_epoch(model, val_dl, writer, epoch_no, total_epoch, device, log=True):
    with tqdm(val_dl, unit="batch") as tepoch:
        epoch_loss = 0
        _classifier_loss = 0
        _loss_box_reg = 0
        _loss_rpn_box_reg = 0
        _loss_objectness = 0
        for data in tepoch:
            tepoch.set_description(f"Val:Epoch {epoch_no}/{total_epoch}")
            imgs = []
            targets = []
            for d in data:
                imgs.append(d[0].to(device))
                targ = {}
                targ["boxes"] = d[1]["boxes"].to(device)
                targ["labels"] = d[1]["labels"].to(device)
                targets.append(targ)
            loss_dict = model(imgs, targets)

            loss = sum(v for v in loss_dict.values())
            classifier_loss = loss_dict.get("loss_classifier").cpu().detach().numpy()
            loss_box_reg = loss_dict.get("loss_box_reg").cpu().detach().numpy()
            loss_objectness = loss_dict.get("loss_objectness").cpu().detach().numpy()
            loss_rpn_box_reg = loss_dict.get("loss_rpn_box_reg").cpu().detach().numpy()

            epoch_loss += loss.cpu().detach().numpy()
            _classifier_loss += classifier_loss
            _loss_box_reg += loss_box_reg
            _loss_objectness += loss_objectness
            _loss_rpn_box_reg += loss_rpn_box_reg

            tepoch.set_postfix(
                total_loss=epoch_loss,
                loss_classifier=_classifier_loss,
                boxreg_loss=_loss_box_reg,
                obj_loss=_loss_objectness,
                rpn_boxreg_loss=_loss_rpn_box_reg,
            )

        if log:
            writer.add_scalar("Val/total_loss", epoch_loss, epoch_no)
            writer.add_scalar("Val/classifier_loss", _classifier_loss, epoch_no)
            writer.add_scalar("Val/box_reg_loss", _loss_box_reg, epoch_no)
            writer.add_scalar("Val/objectness_loss", _loss_objectness, epoch_no)
            writer.add_scalar("Val/rpn_box_reg_loss", _loss_rpn_box_reg, epoch_no)

    return writer, epoch_loss

def train_one_epoch(model, train_dl, optimizer, writer, epoch_no, total_epoch, device):
    with tqdm(train_dl, unit="batch") as tepoch:
        epoch_loss = 0
        _classifier_loss = 0
        _loss_box_reg = 0
        _loss_rpn_box_reg = 0
        _loss_objectness = 0
        for data in tepoch:
            tepoch.set_description(f"Train:Epoch {epoch_no}/{total_epoch}")
            imgs = []
            targets = []
            for d in data:
                imgs.append(d[0].to(device))
                targ = {}
                targ["boxes"] = d[1]["boxes"].to(device)
                targ["labels"] = d[1]["labels"].to(device)
                targets.append(targ)
            loss_dict = model(imgs, targets)

            loss = sum(v for v in loss_dict.values())
            classifier_loss = loss_dict.get("loss_classifier").cpu().detach().numpy()
            loss_box_reg = loss_dict.get("loss_box_reg").cpu().detach().numpy()
            loss_objectness = loss_dict.get("loss_objectness").cpu().detach().numpy()
            loss_rpn_box_reg = loss_dict.get("loss_rpn_box_reg").cpu().detach().numpy()

            epoch_loss += loss.cpu().detach().numpy()
            _classifier_loss += classifier_loss
            _loss_box_reg += loss_box_reg
            _loss_objectness += loss_objectness
            _loss_rpn_box_reg += loss_rpn_box_reg

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            tepoch.set_postfix(
                total_loss=epoch_loss,
                loss_classifier=_classifier_loss,
                boxreg_loss=_loss_box_reg,
                obj_loss=_loss_objectness,
                rpn_boxreg_loss=_loss_rpn_box_reg,
            )

        writer.add_scalar("Train/total_loss", epoch_loss, epoch_no)
        writer.add_scalar("Train/classifier_loss", _classifier_loss, epoch_no)
        writer.add_scalar("Train/box_reg_loss", _loss_box_reg, epoch_no)
        writer.add_scalar("Train/objectness_loss", _loss_objectness, epoch_no)
        writer.add_scalar("Train/rpn_box_reg_loss", _loss_rpn_box_reg, epoch_no)

    return model, optimizer, writer, epoch_loss

# %%
def save_json(data, file_path):
    def convert(o):
        if isinstance(o, np.float32):
            return float(o)
        raise TypeError(f'Object of type {o.__class__.__name__} is not JSON serializable')

    with open(file_path, 'w') as file:
        json.dump(data, file, default=convert)

def evaluate_model(image_dir,
                   gt_ann_file,
                   model_weight):
    
    _ds = CocoDataset(
            image_folder=image_dir,
            annotations_file=gt_ann_file,
            height=640,
            width=640,
        )
    
    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

    IF_C = InferFasterRCNN(num_classes=_ds.get_total_classes_count() + 1,
                        classnames=_ds.get_classnames())

    IF_C.load_model(checkpoint=model_weight,
                    device=device)

    image_dir = image_dir

    cocoGt=COCO(annotation_file=gt_ann_file)
    imgIds = cocoGt.getImgIds() # all image ids

    res_id = 1
    res_all = []
        
    for id in tqdm(imgIds,total=len(imgIds)):
        id = id
        img_info = cocoGt.loadImgs(imgIds[id])[0]
        annIds = cocoGt.getAnnIds(imgIds=img_info['id'])
        ann_info = cocoGt.loadAnns(annIds)
        image_path = os.path.join(image_dir, 
                                img_info['file_name'])
        transform_info = CocoDataset.transform_image_for_inference(image_path,width=640,height=640)
        result = IF_C.infer_image(transform_info=transform_info,
                                visualize=False)

        if len(result)>0:
            pred_boxes_xyxy = result['unscaled_boxes']
            pred_boxes_xywh = [[i[0],i[1],i[2]-i[0],i[3]-i[1]] for i in pred_boxes_xyxy]
            pred_classes = result['pred_classes']
            pred_scores = result['scores']
            pred_labels = result['labels']

            for i in range(len(pred_boxes_xywh)):
                res_temp = {"id":res_id,
                            "image_id":id,
                            "bbox":pred_boxes_xywh[i],
                            "segmentation":[],
                            "iscrowd": 0,
                            "category_id": int(pred_labels[i]),
                            "area":pred_boxes_xywh[i][2]*pred_boxes_xywh[i][3],
                            "score": float(pred_scores[i])}
                res_all.append(res_temp)
                res_id+=1

    save_json_path = 'test_dect.json'
    save_json(res_all,save_json_path)
    
    cocoGt=COCO(gt_ann_file)
    cocoDt=cocoGt.loadRes(save_json_path)

    cocoEval = COCOeval(cocoGt,cocoDt,iouType='bbox')
    cocoEval.evaluate()
    cocoEval.accumulate()
    cocoEval.summarize()
    
    AP_50_95 = cocoEval.stats.tolist()[0]
    AP_50 = cocoEval.stats.tolist()[1]
    
    del IF_C,_ds
    os.remove(save_json_path)
    
    torch.cuda.empty_cache()
    gc.collect()
    
    return {'AP_50_95':AP_50_95,
            'AP_50':AP_50}

# %%
def train(
    train_dataset,
    val_dataset,
    epochs=2,
    batch_size=8,
    exp_folder="exp",
    val_eval_freq=1,
):

    date_format = "%d-%m-%Y-%H-%M-%S"
    date_string = time.strftime(date_format)

    exp_folder = os.path.join("exp", "summary", date_string)
    writer = SummaryWriter(exp_folder)

    def custom_collate(data):
        return data

    train_dl = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        collate_fn=custom_collate,
        pin_memory=True if torch.cuda.is_available() else False,
    )

    val_dl = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        collate_fn=custom_collate,
        pin_memory=True if torch.cuda.is_available() else False,
    )

    # Device --
    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

    # Model --
    faster_rcnn_model = create_model(train_dataset.get_total_classes_count() + 1)
    faster_rcnn_model = faster_rcnn_model.to(device)

    # Optimizer --
    pg0, pg1, pg2 = [], [], []  # optimizer parameter groups

    for k, v in faster_rcnn_model.named_modules():
        if hasattr(v, "bias") and isinstance(v.bias, torch.nn.Parameter):
            pg2.append(v.bias)  # biases
        if isinstance(v, torch.nn.BatchNorm2d) or "bn" in k:
            pg0.append(v.weight)  # no decay
        elif hasattr(v, "weight") and isinstance(v.weight, torch.nn.Parameter):
            pg1.append(v.weight)  # apply decay

    optimizer = torch.optim.SGD(
        pg0, lr=0.001, momentum=0.9, nesterov=True
    ) # BN
    
    optimizer.add_param_group(
        {"params": pg1, "weight_decay":  5e-4}
    )  # add pg1 with weight_decay # Weights
    
    optimizer.add_param_group({"params": pg2}) # Biases
    

    num_epochs = epochs
    save_best_model = SaveBestModel(output_dir=exp_folder)

    for epoch in range(num_epochs):

        faster_rcnn_model, optimizer, writer, epoch_loss = train_one_epoch(
            faster_rcnn_model,
            train_dl,
            optimizer,
            writer,
            epoch + 1,
            num_epochs,
            device,
        )
        
        time.sleep(0.1)

        if (epoch % val_eval_freq == 0) and epoch != 0:  # Do evaluation of validation set
            eval_result = evaluate_model(image_dir=val_dataset.image_folder,
                                         gt_ann_file=val_dataset.annotations_file,
                                         model_weight=save_best_model.model_save_path)
            
            time.sleep(0.1)
            
            writer.add_scalar("Val/AP_50_95", eval_result['AP_50_95'], epoch + 1)
            writer.add_scalar("Val/AP_50", eval_result['AP_50'], epoch + 1)
        
        else:
            writer, val_epoch_loss = val_one_epoch(
                faster_rcnn_model,
                val_dl,
                writer,
                epoch + 1,
                num_epochs,
                device,
                log=True,
            )
        
            time.sleep(0.1)
            
            save_best_model(val_epoch_loss, 
                            epoch, 
                            faster_rcnn_model, 
                            optimizer)
            

    _, _ = val_one_epoch(
        faster_rcnn_model, val_dl, writer, epoch + 1, num_epochs, device, log=False
    )

    writer.add_hparams(
        {"epochs": epochs, "batch_size": batch_size},
        {"Train/total_loss": epoch_loss, "Val/total_loss": val_epoch_loss},
    )

# %% [markdown]
# ## Entrenamiento - dataset 3 - tran 1

# %%
train_image_dir = r"/home/isidro-marco/proyectos/CEIA/materias/bimestre4/vc2/vpc-II/datasets/dataset_coco_3/train"
val_image_dir = r"/home/isidro-marco/proyectos/CEIA/materias/bimestre4/vc2/vpc-II/datasets/dataset_coco_3/valid"
test_image_dir = r"/home/isidro-marco/proyectos/CEIA/materias/bimestre4/vc2/vpc-II/datasets/dataset_coco_3/test"
train_coco_json = r"/home/isidro-marco/proyectos/CEIA/materias/bimestre4/vc2/vpc-II/datasets/dataset_coco_3/train/_annotations.coco.json"
val_coco_json = r"/home/isidro-marco/proyectos/CEIA/materias/bimestre4/vc2/vpc-II/datasets/dataset_coco_3/valid/_annotations.coco.json"
test_coco_json = r"/home/isidro-marco/proyectos/CEIA/materias/bimestre4/vc2/vpc-II/datasets/dataset_coco_3/test/_annotations.coco.json"

epochs = 15
batch_size = 4
val_eval_freq = 5
exp_folder = 'results/faster_rcnn_results'

# %%
train_ds, val_ds, test_ds = get_datasets(train_image_dir=train_image_dir,
                                    train_coco_json=train_coco_json,
                                    val_image_dir=val_image_dir,
                                    val_coco_json=val_coco_json,
                                    test_image_dir=test_image_dir,
                                    test_coco_json=test_coco_json)

# %%
train(train_ds, val_ds,
          epochs=epochs, 
          batch_size=batch_size,
          val_eval_freq=val_eval_freq,
          exp_folder=exp_folder)
# Out:
# /home/isidro-marco/.cache/pypoetry/virtualenvs/vpc-ii-2tCthqWZ-py3.12/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained_backbone' is deprecated since 0.13 and may be removed in the future, please use 'weights_backbone' instead.
#   warnings.warn(
# /home/isidro-marco/.cache/pypoetry/virtualenvs/vpc-ii-2tCthqWZ-py3.12/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights_backbone' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights_backbone=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights_backbone=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Train:Epoch 1/15: 100%|██████████| 423/423 [08:47<00:00,  1.25s/batch, boxreg_loss=119, loss_classifier=105, obj_loss=17.5, rpn_boxreg_loss=11.5, total_loss=253]
# Val:Epoch 1/15: 100%|██████████| 41/41 [00:41<00:00,  1.00s/batch, boxreg_loss=9.75, loss_classifier=7.22, obj_loss=1.11, rpn_boxreg_loss=0.926, total_loss=19]
# Best validation loss: 19.003620147705078
#
# Saving best model for epoch: 1
# Train:Epoch 2/15: 100%|██████████| 423/423 [14:16<00:00,  2.03s/batch, boxreg_loss=96.1, loss_classifier=74.1, obj_loss=7.44, rpn_boxreg_loss=8.55, total_loss=186]
# Val:Epoch 2/15: 100%|██████████| 41/41 [00:40<00:00,  1.00batch/s, boxreg_loss=9.67, loss_classifier=6.79, obj_loss=0.945, rpn_boxreg_loss=0.939, total_loss=18.3]
# Best validation loss: 18.33844566345215
#
# Saving best model for epoch: 2
# Train:Epoch 3/15: 100%|██████████| 423/423 [06:19<00:00,  1.11batch/s, boxreg_loss=90.1, loss_classifier=66.2, obj_loss=5.41, rpn_boxreg_loss=7.69, total_loss=169]
# Val:Epoch 3/15: 100%|██████████| 41/41 [00:12<00:00,  3.28batch/s, boxreg_loss=9.57, loss_classifier=6.28, obj_loss=0.805, rpn_boxreg_loss=0.965, total_loss=17.6]
# Best validation loss: 17.61784553527832
#
# Saving best model for epoch: 3
# Train:Epoch 4/15: 100%|██████████| 423/423 [04:13<00:00,  1.67batch/s, boxreg_loss=87.1, loss_classifier=60.6, obj_loss=4.29, rpn_boxreg_loss=7.12, total_loss=159]
# Val:Epoch 4/15: 100%|██████████| 41/41 [00:12<00:00,  3.28batch/s, boxreg_loss=8.89, loss_classifier=6.31, obj_loss=0.928, rpn_boxreg_loss=0.884, total_loss=17]
# Best validation loss: 17.00993537902832
#
# Saving best model for epoch: 4
# Train:Epoch 5/15: 100%|██████████| 423/423 [04:13<00:00,  1.67batch/s, boxreg_loss=83.2, loss_classifier=54.8, obj_loss=3.49, rpn_boxreg_loss=6.61, total_loss=148]
# Val:Epoch 5/15: 100%|██████████| 41/41 [00:12<00:00,  3.29batch/s, boxreg_loss=8.74, loss_classifier=6.29, obj_loss=0.793, rpn_boxreg_loss=0.861, total_loss=16.7]
# Best validation loss: 16.679475784301758
#
# Saving best model for epoch: 5
# Train:Epoch 6/15: 100%|██████████| 423/423 [12:34<00:00,  1.78s/batch, boxreg_loss=79.5, loss_classifier=49.7, obj_loss=2.95, rpn_boxreg_loss=6.34, total_loss=139]
# /tmp/ipykernel_157826/134245011.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint, map_location=device)
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 100%|██████████| 161/161 [00:43<00:00,  3.70it/s]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.13s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.339
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.380
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.417
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.483
# Train:Epoch 7/15: 100%|██████████| 423/423 [04:18<00:00,  1.64batch/s, boxreg_loss=76.5, loss_classifier=45, obj_loss=2.34, rpn_boxreg_loss=6.03, total_loss=130]
# Val:Epoch 7/15: 100%|██████████| 41/41 [00:12<00:00,  3.24batch/s, boxreg_loss=9.5, loss_classifier=6.61, obj_loss=1.03, rpn_boxreg_loss=0.865, total_loss=18]
# Train:Epoch 8/15: 100%|██████████| 423/423 [05:35<00:00,  1.26batch/s, boxreg_loss=73.3, loss_classifier=40.2, obj_loss=2.04, rpn_boxreg_loss=5.7, total_loss=121]
# Val:Epoch 8/15: 100%|██████████| 41/41 [00:12<00:00,  3.21batch/s, boxreg_loss=8.66, loss_classifier=6.9, obj_loss=1.15, rpn_boxreg_loss=0.842, total_loss=17.6]
# Train:Epoch 9/15: 100%|██████████| 423/423 [08:55<00:00,  1.27s/batch, boxreg_loss=69.4, loss_classifier=35.7, obj_loss=1.72, rpn_boxreg_loss=5.38, total_loss=112]
# Val:Epoch 9/15: 100%|██████████| 41/41 [00:39<00:00,  1.04batch/s, boxreg_loss=8.95, loss_classifier=7.56, obj_loss=1.56, rpn_boxreg_loss=0.885, total_loss=18.9]
# Train:Epoch 10/15: 100%|██████████| 423/423 [14:38<00:00,  2.08s/batch, boxreg_loss=66, loss_classifier=31.9, obj_loss=1.42, rpn_boxreg_loss=5.11, total_loss=104]
# Val:Epoch 10/15: 100%|██████████| 41/41 [00:40<00:00,  1.01batch/s, boxreg_loss=9.52, loss_classifier=8.47, obj_loss=1.72, rpn_boxreg_loss=0.916, total_loss=20.6]
# Train:Epoch 11/15: 100%|██████████| 423/423 [15:18<00:00,  2.17s/batch, boxreg_loss=62.7, loss_classifier=29.2, obj_loss=1.27, rpn_boxreg_loss=4.85, total_loss=97.9]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 100%|██████████| 161/161 [00:44<00:00,  3.59it/s]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.15s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.339
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.380
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.417
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.483
# Train:Epoch 12/15: 100%|██████████| 423/423 [16:03<00:00,  2.28s/batch, boxreg_loss=59.5, loss_classifier=26.9, obj_loss=1.17, rpn_boxreg_loss=4.6, total_loss=92.1]
# Val:Epoch 12/15: 100%|██████████| 41/41 [00:41<00:00,  1.02s/batch, boxreg_loss=8.79, loss_classifier=9.17, obj_loss=2.09, rpn_boxreg_loss=0.898, total_loss=20.9]
# Train:Epoch 13/15: 100%|██████████| 423/423 [16:07<00:00,  2.29s/batch, boxreg_loss=56, loss_classifier=24.9, obj_loss=0.933, rpn_boxreg_loss=4.37, total_loss=86.3]
# Val:Epoch 13/15: 100%|██████████| 41/41 [00:41<00:00,  1.01s/batch, boxreg_loss=9.18, loss_classifier=10.3, obj_loss=2.7, rpn_boxreg_loss=0.877, total_loss=23]
# Train:Epoch 14/15: 100%|██████████| 423/423 [16:05<00:00,  2.28s/batch, boxreg_loss=52.4, loss_classifier=22.7, obj_loss=0.858, rpn_boxreg_loss=4.11, total_loss=80]
# Val:Epoch 14/15: 100%|██████████| 41/41 [00:41<00:00,  1.01s/batch, boxreg_loss=9.25, loss_classifier=10.2, obj_loss=2.78, rpn_boxreg_loss=0.857, total_loss=23]
# Train:Epoch 15/15: 100%|██████████| 423/423 [15:56<00:00,  2.26s/batch, boxreg_loss=49.1, loss_classifier=21.1, obj_loss=0.696, rpn_boxreg_loss=3.81, total_loss=74.8]
# Val:Epoch 15/15: 100%|██████████| 41/41 [00:39<00:00,  1.04batch/s, boxreg_loss=9.09, loss_classifier=10.3, obj_loss=3.01, rpn_boxreg_loss=0.901, total_loss=23.3]
# Val:Epoch 15/15: 100%|██████████| 41/41 [00:38<00:00,  1.07batch/s, boxreg_loss=9.09, loss_classifier=10.2, obj_loss=2.98, rpn_boxreg_loss=0.899, total_loss=23.2]

# %%
# %load_ext tensorboard
# %tensorboard --logdir ../results/faster_rcnn_results
# Out:
#       <iframe id="tensorboard-frame-73e0d6ffd498799c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-73e0d6ffd498799c");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
